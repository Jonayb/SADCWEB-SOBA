# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanvanberkum/CD-ABSC/blob/main/getBERT_laptop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
For use on local runtime.

How to run:
- Download the appropriate BERT model from: 
  https://github.com/google-research/bert (here BERT-Base).

- Create a virtual environment (e.g. using anaconda).

- Install tensorflow in your virtual environment (pip install tensorflow==1.15).

- Start a local runtime in your virtual environment using
  https://research.google.com/colaboratory/local-runtimes.html

- Make sure the BERT model is in your system path (here named
  'uncased_L-12_H-768_A-12').

- Make sure all data is available and update the paths at the end of this code.

Adapted from Trusca, Wassenberg, Frasincar and Dekker (2020) for use on a local
runtime

Truşcǎ M.M., Wassenberg D., Frasincar F., Dekker R. (2020) A Hybrid Approach for 
Aspect-Based Sentiment Analysis Using Deep Contextual Word Embeddings and 
Hierarchical Attention. In: Bielikova M., Mikkonen T., Pautasso C. (eds) Web 
Engineering. ICWE 2020. Lecture Notes in Computer Science, vol 12128. Springer, 
Cham. https://doi.org/10.1007/978-3-030-50578-3_25

https://github.com/mtrusca/HAABSA_PLUS_PLUS
'''
# Out:
# "\nFor use on local runtime.\n\nHow to run:\n- Download the appropriate BERT model from: \n  https://github.com/google-research/bert (here BERT-Base).\n\n- Create a virtual environment (e.g. using anaconda).\n\n- Install tensorflow in your virtual environment (pip install tensorflow==1.15).\n\n- Start a local runtime in your virtual environment using\n  https://research.google.com/colaboratory/local-runtimes.html\n\n- Make sure the BERT model is in your system path (here named\n  'uncased_L-12_H-768_A-12').\n\n- Make sure all data is available and update the paths at the end of this code.\n\nAdapted from Trusca, Wassenberg, Frasincar and Dekker (2020) for use on a local\nruntime\n\nTruşcǎ M.M., Wassenberg D., Frasincar F., Dekker R. (2020) A Hybrid Approach for \nAspect-Based Sentiment Analysis Using Deep Contextual Word Embeddings and \nHierarchical Attention. In: Bielikova M., Mikkonen T., Pautasso C. (eds) Web \nEngineering. ICWE 2020. Lecture Notes in Computer Science, vol 12128. Springer, \nCham. https://doi.org/10.1007/978-3-030-50578-3_25\n\nhttps://github.com/mtrusca/HAABSA_PLUS_PLUS\n"

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import sys

sys.path.append('bert-master/')

import codecs
import collections
import json
import re
import os
import pprint
import numpy as np
import tensorflow as tf

import modeling
import tokenization

# %%
BERT_MODEL = 'uncased_L-12_H-768_A-12'
BERT_PRETRAINED_DIR = 'uncased_L-12_H-768_A-12'
LAYERS = [-1, -2, -3, -4]
NUM_TPU_CORES = 8
MAX_SEQ_LENGTH = 87
BERT_CONFIG = BERT_PRETRAINED_DIR + '/bert_config.json'
CKPT_DIR = BERT_PRETRAINED_DIR + '/bert_model.ckpt'
VOCAB_FILE = BERT_PRETRAINED_DIR + '/vocab.txt'
INIT_CHECKPOINT = BERT_PRETRAINED_DIR + '/bert_model.ckpt'
BATCH_SIZE = 128

# %%
class InputExample(object):

    def __init__(self, unique_id, text_a, text_b=None):
        self.unique_id = unique_id
        self.text_a = text_a
        self.text_b = text_b

# %%
class InputFeatures(object):
    """A single set of features of data."""

    def __init__(self, unique_id, tokens, input_ids, input_mask, input_type_ids):
        self.unique_id = unique_id
        self.tokens = tokens
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.input_type_ids = input_type_ids

# %%
def input_fn_builder(features, seq_length):
    """Creates an `input_fn` closure to be passed to TPUEstimator."""

    all_unique_ids = []
    all_input_ids = []
    all_input_mask = []
    all_input_type_ids = []

    for feature in features:
        all_unique_ids.append(feature.unique_id)
        all_input_ids.append(feature.input_ids)
        all_input_mask.append(feature.input_mask)
        all_input_type_ids.append(feature.input_type_ids)

    def input_fn(params):
        """The actual input function."""
        batch_size = params["batch_size"]

        num_examples = len(features)

        # This is for demo purposes and does NOT scale to large data sets. We do
        # not use Dataset.from_generator() because that uses tf.py_func which is
        # not TPU compatible. The right way to load data is with TFRecordReader.
        d = tf.data.Dataset.from_tensor_slices({
            "unique_ids":
                tf.constant(all_unique_ids, shape=[num_examples], dtype=tf.int32),
            "input_ids":
                tf.constant(
                    all_input_ids, shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "input_mask":
                tf.constant(
                    all_input_mask,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "input_type_ids":
                tf.constant(
                    all_input_type_ids,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
        })

        d = d.batch(batch_size=batch_size, drop_remainder=False)
        return d

    return input_fn

# %%
def model_fn_builder(bert_config, init_checkpoint, layer_indexes, use_tpu,
                     use_one_hot_embeddings):
    """Returns `model_fn` closure for TPUEstimator."""

    def model_fn(features, labels, mode, params):  # pylint: disable=unused-argument
        """The `model_fn` for TPUEstimator."""

        unique_ids = features["unique_ids"]
        input_ids = features["input_ids"]
        input_mask = features["input_mask"]
        input_type_ids = features["input_type_ids"]

        model = modeling.BertModel(
            config=bert_config,
            is_training=False,
            input_ids=input_ids,
            input_mask=input_mask,
            token_type_ids=input_type_ids,
            use_one_hot_embeddings=use_one_hot_embeddings)

        if mode != tf.estimator.ModeKeys.PREDICT:
            raise ValueError("Only PREDICT modes are supported: %s" % (mode))

        tvars = tf.trainable_variables()
        scaffold_fn = None
        (assignment_map,
         initialized_variable_names) = modeling.get_assignment_map_from_checkpoint(
            tvars, init_checkpoint)
        if use_tpu:

            def tpu_scaffold():
                tf.train.init_from_checkpoint(init_checkpoint, assignment_map)
                return tf.train.Scaffold()

            scaffold_fn = tpu_scaffold
        else:
            tf.train.init_from_checkpoint(init_checkpoint, assignment_map)

        tf.logging.info("**** Trainable Variables ****")
        for var in tvars:
            init_string = ""
            if var.name in initialized_variable_names:
                init_string = ", *INIT_FROM_CKPT*"
            tf.logging.info("  name = %s, shape = %s%s", var.name, var.shape,
                            init_string)

        all_layers = model.get_all_encoder_layers()

        predictions = {
            "unique_id": unique_ids,
        }

        for (i, layer_index) in enumerate(layer_indexes):
            predictions["layer_output_%d" % i] = all_layers[layer_index]

        output_spec = tf.contrib.tpu.TPUEstimatorSpec(
            mode=mode, predictions=predictions, scaffold_fn=scaffold_fn)
        return output_spec

    return model_fn

# %%
def convert_examples_to_features(examples, seq_length, tokenizer):
    """Loads a data file into a list of `InputBatch`s."""

    features = []
    for (ex_index, example) in enumerate(examples):
        tokens_a = tokenizer.tokenize(example.text_a)

        tokens_b = None
        if example.text_b:
            tokens_b = tokenizer.tokenize(example.text_b)

        if tokens_b:
            # Modifies `tokens_a` and `tokens_b` in place so that the total
            # length is less than the specified length.
            # Account for [CLS], [SEP], [SEP] with "- 3"
            _truncate_seq_pair(tokens_a, tokens_b, seq_length - 3)
        else:
            # Account for [CLS] and [SEP] with "- 2"
            if len(tokens_a) > seq_length - 2:
                tokens_a = tokens_a[0:(seq_length - 2)]

        tokens = []
        input_type_ids = []
        tokens.append("[CLS]")
        input_type_ids.append(0)
        for token in tokens_a:
            tokens.append(token)
            input_type_ids.append(0)
        tokens.append("[SEP]")
        input_type_ids.append(0)

        if tokens_b:
            for token in tokens_b:
                tokens.append(token)
                input_type_ids.append(1)
            tokens.append("[SEP]")
            input_type_ids.append(1)

        input_ids = tokenizer.convert_tokens_to_ids(tokens)

        # The mask has 1 for real tokens and 0 for padding tokens. Only real
        # tokens are attended to.
        input_mask = [1] * len(input_ids)

        # Zero-pad up to the sequence length.
        while len(input_ids) < seq_length:
            input_ids.append(0)
            input_mask.append(0)
            input_type_ids.append(0)

        assert len(input_ids) == seq_length
        assert len(input_mask) == seq_length
        assert len(input_type_ids) == seq_length

        if ex_index < 5:
            tf.logging.info("*** Example ***")
            tf.logging.info("unique_id: %s" % (example.unique_id))
            tf.logging.info("tokens: %s" % " ".join(
                [tokenization.printable_text(x) for x in tokens]))
            tf.logging.info("input_ids: %s" % " ".join([str(x) for x in input_ids]))
            tf.logging.info("input_mask: %s" % " ".join([str(x) for x in input_mask]))
            tf.logging.info(
                "input_type_ids: %s" % " ".join([str(x) for x in input_type_ids]))

        features.append(
            InputFeatures(
                unique_id=example.unique_id,
                tokens=tokens,
                input_ids=input_ids,
                input_mask=input_mask,
                input_type_ids=input_type_ids))
    return features

# %%
def _truncate_seq_pair(tokens_a, tokens_b, max_length):
    """Truncates a sequence pair in place to the maximum length."""

    # This is a simple heuristic which will always truncate the longer sequence
    # one token at a time. This makes more sense than truncating an equal percent
    # of tokens from each, since if one sequence is very short then each token
    # that's truncated likely contains more information than a longer sequence.
    while True:
        total_length = len(tokens_a) + len(tokens_b)
        if total_length <= max_length:
            break
        if len(tokens_a) > len(tokens_b):
            tokens_a.pop()
        else:
            tokens_b.pop()

# %%
def read_sequence(input_sentences):
    examples = []
    unique_id = 0
    for sentence in input_sentences:
        line = tokenization.convert_to_unicode(sentence)
        examples.append(InputExample(unique_id=unique_id, text_a=line))
        unique_id += 1
    return examples

# %%
def get_features(input_text, dim=768):
    tf.logging.set_verbosity(tf.logging.ERROR)

    layer_indexes = LAYERS

    bert_config = modeling.BertConfig.from_json_file(BERT_CONFIG);

    tokenizer = tokenization.FullTokenizer(
        vocab_file=VOCAB_FILE, do_lower_case=True)

    examples = read_sequence(input_text)

    features = convert_examples_to_features(
        examples=examples, seq_length=MAX_SEQ_LENGTH, tokenizer=tokenizer)

    unique_id_to_feature = {}
    for feature in features:
        unique_id_to_feature[feature.unique_id] = feature

    model_fn = model_fn_builder(
        bert_config=bert_config,
        init_checkpoint=INIT_CHECKPOINT,
        layer_indexes=layer_indexes,
        use_tpu=False,
        use_one_hot_embeddings=True)

    # If TPU is not available, this will fall back to normal Estimator on CPU
    # or GPU.
    estimator = tf.contrib.tpu.TPUEstimator(
        model_dir=BERT_PRETRAINED_DIR,
        use_tpu=False,
        model_fn=model_fn,
        config=tf.contrib.tpu.RunConfig(),
        predict_batch_size=BATCH_SIZE,
        train_batch_size=BATCH_SIZE)

    input_fn = input_fn_builder(
        features=features, seq_length=MAX_SEQ_LENGTH)

    # Get features
    for result in estimator.predict(input_fn, yield_single_examples=True):
        unique_id = int(result["unique_id"])
        feature = unique_id_to_feature[unique_id]
        output = collections.OrderedDict()
        for (i, token) in enumerate(feature.tokens):
            layers = []
            for (j, layer_index) in enumerate(layer_indexes):
                layer_output = result["layer_output_%d" % j]
                layer_output_flat = np.array([x for x in layer_output[i:(i + 1)].flat])
                layers.append(layer_output_flat)
            output[token] = sum(layers)[:dim]

    return output

# %%
# When it takes too long, data can be split in multiple subfiles such as in
# lines 5-30
lines = open('data/programGeneratedData/BERT/laptop/raw_data_laptop_train_2014.txt', errors='replace').readlines()


for j in range(0, len(lines), 150):
  with open("BERT_base_laptop_2014_" + str(round(j/150)) + ".txt", 'w') as f:
      for i in range(j, j + 150, 3):  # Was 0*3, 2530*3, 3
          print("sentence: " + str(i / 3) + " out of " + str(len(lines) / 3) + " in " + "raw_data;")
          target = lines[i + 1].lower().split()
          words = lines[i].lower().split()
          words_l, words_r = [], []
          flag = True
          for word in words:
              if word == '$t$':
                  flag = False
                  continue
              if flag:
                  words_l.append(word)
              else:
                  words_r.append(word)
          sentence = " ".join(words_l + target + words_r)
          print(sentence)
          embeddings = get_features([sentence])

          for key, value in embeddings.items():
              f.write('\n%s ' % key)
              for v in value:
                f.write('%s ' % v)

'''
with open("data/externalData/BERT_base_laptop_2014.txt", 'w') as f:
  for i in range(0, len(lines), 3):  # Was 0*3, 2530*3, 3
    print("sentence: " + str(i / 3) + " out of " + str(len(lines) / 3) + " in " + "raw_data;")
    target = lines[i + 1].lower().split()
    words = lines[i].lower().split()
    words_l, words_r = [], []
    flag = True
    for word in words:
      if word == '$t$':
        flag = False
        continue
      if flag:
        words_l.append(word)
      else:
        words_r.append(word)
    sentence = " ".join(words_l + target + words_r)
    print(sentence)
    embeddings = get_features([sentence])

    for key, value in embeddings.items():
      f.write('\n%s ' % key)
      for v in value:
        f.write('%s ' % v)
'''
# Out:
# sentence: 0.0 out of 2313.0 in raw_data;
# i charge it at night and skip taking the cord with me because of the good battery life .
# sentence: 1.0 out of 2313.0 in raw_data;
# i charge it at night and skip taking the cord with me because of the good battery life .
# sentence: 2.0 out of 2313.0 in raw_data;
# the tech guy then said the service center does not do 1-to-1 exchange and i have to direct my concern to the `` sales '' team , which is the retail shop which i bought my netbook from .
# sentence: 3.0 out of 2313.0 in raw_data;
# the tech guy then said the service center does not do 1-to-1 exchange and i have to direct my concern to the `` sales '' team , which is the retail shop which i bought my netbook from .
# sentence: 4.0 out of 2313.0 in raw_data;
# the tech guy then said the service center does not do 1-to-1 exchange and i have to direct my concern to the `` sales '' team , which is the retail shop which i bought my netbook from .
# sentence: 5.0 out of 2313.0 in raw_data;
# it is of high quality , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to use , and is absolutely gorgeous .
# sentence: 6.0 out of 2313.0 in raw_data;
# it is of high quality , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to use , and is absolutely gorgeous .
# sentence: 7.0 out of 2313.0 in raw_data;
# it is of high quality , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to use , and is absolutely gorgeous .
# sentence: 8.0 out of 2313.0 in raw_data;
# it is of high quality , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to use , and is absolutely gorgeous .
# sentence: 9.0 out of 2313.0 in raw_data;
# easy to start up and does not overheat as much as other laptops .
# sentence: 10.0 out of 2313.0 in raw_data;
# i even got my teenage son one , because of the features that it offers , like , ichat , photobooth , garage band and more !
# sentence: 11.0 out of 2313.0 in raw_data;
# i even got my teenage son one , because of the features that it offers , like , ichat , photobooth , garage band and more !
# sentence: 12.0 out of 2313.0 in raw_data;
# i even got my teenage son one , because of the features that it offers , like , ichat , photobooth , garage band and more !
# sentence: 13.0 out of 2313.0 in raw_data;
# i even got my teenage son one , because of the features that it offers , like , ichat , photobooth , garage band and more !
# sentence: 14.0 out of 2313.0 in raw_data;
# great laptop that offers many great features !
# sentence: 15.0 out of 2313.0 in raw_data;
# one night i turned the freaking thing off after using it , the next day i turn it on , no gui , screen all dark , power light steady , hard drive light steady and not flashing as it usually does .
# sentence: 16.0 out of 2313.0 in raw_data;
# one night i turned the freaking thing off after using it , the next day i turn it on , no gui , screen all dark , power light steady , hard drive light steady and not flashing as it usually does .
# sentence: 17.0 out of 2313.0 in raw_data;
# one night i turned the freaking thing off after using it , the next day i turn it on , no gui , screen all dark , power light steady , hard drive light steady and not flashing as it usually does .
# sentence: 18.0 out of 2313.0 in raw_data;
# one night i turned the freaking thing off after using it , the next day i turn it on , no gui , screen all dark , power light steady , hard drive light steady and not flashing as it usually does .
# sentence: 19.0 out of 2313.0 in raw_data;
# i took it back for an asus and same thing- blue screen which required me to remove the battery to reset .
# sentence: 20.0 out of 2313.0 in raw_data;
# in the shop , these macbooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it , get it home , break the seal and use it ( very clever con ) .
# sentence: 21.0 out of 2313.0 in raw_data;
# in the shop , these macbooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it , get it home , break the seal and use it ( very clever con ) .
# sentence: 22.0 out of 2313.0 in raw_data;
# however , the multi-touch gestures and large tracking area make having an external mouse unnecessary ( unless you 're gaming ) .
# sentence: 23.0 out of 2313.0 in raw_data;
# however , the multi-touch gestures and large tracking area make having an external mouse unnecessary ( unless you 're gaming ) .
# sentence: 24.0 out of 2313.0 in raw_data;
# however , the multi-touch gestures and large tracking area make having an external mouse unnecessary ( unless you 're gaming ) .
# sentence: 25.0 out of 2313.0 in raw_data;
# however , the multi-touch gestures and large tracking area make having an external mouse unnecessary ( unless you 're gaming ) .
# sentence: 26.0 out of 2313.0 in raw_data;
# i love the way the entire suite of software works together .
# sentence: 27.0 out of 2313.0 in raw_data;
# the speed is incredible and i am more than satisfied .
# sentence: 28.0 out of 2313.0 in raw_data;
# this laptop meets every expectation and windows 7 is great !
# sentence: 29.0 out of 2313.0 in raw_data;
# i can barely use any usb devices because they will not stay connected properly .
# sentence: 30.0 out of 2313.0 in raw_data;
# when i finally had everything running with all my software installed i plugged in my droid to recharge and the system crashed .
# sentence: 31.0 out of 2313.0 in raw_data;
# when i finally had everything running with all my software installed i plugged in my droid to recharge and the system crashed .
# sentence: 32.0 out of 2313.0 in raw_data;
# one suggestion i do have , is to not bother getting microsoft office for the mac expecting it will work just like you knew it to on a pc .
# sentence: 33.0 out of 2313.0 in raw_data;
# pairing it with an iphone is a pure pleasure - talk about painless syncing - used to take me forever - now it 's a snap .
# sentence: 34.0 out of 2313.0 in raw_data;
# i also got the added bonus of a 30 '' hd monitor , which really helps to extend my screen and keep my eyes fresh !
# sentence: 35.0 out of 2313.0 in raw_data;
# i also got the added bonus of a 30 '' hd monitor , which really helps to extend my screen and keep my eyes fresh !
# sentence: 36.0 out of 2313.0 in raw_data;
# the machine is slow to boot up and occasionally crashes completely .
# sentence: 37.0 out of 2313.0 in raw_data;
# after paying several hundred dollars for this service , it is frustrating that you can not get help after hours .
# sentence: 38.0 out of 2313.0 in raw_data;
# i love the operating system and the preloaded software .
# sentence: 39.0 out of 2313.0 in raw_data;
# i love the operating system and the preloaded software .
# sentence: 40.0 out of 2313.0 in raw_data;
# the best thing about this laptop is the price along with some of the newer features .
# sentence: 41.0 out of 2313.0 in raw_data;
# the best thing about this laptop is the price along with some of the newer features .
# sentence: 42.0 out of 2313.0 in raw_data;
# after numerous attempts of trying ( including setting the clock in bios setup directly ) , i gave up ( i am a techie ) .
# sentence: 43.0 out of 2313.0 in raw_data;
# you will not be able to talk to an american warranty service is out of country .
# sentence: 44.0 out of 2313.0 in raw_data;
# but now i have realized its a problem with this brand .
# sentence: 45.0 out of 2313.0 in raw_data;
# i sent it back to toshiba twice they covered it under the warranty .
# sentence: 46.0 out of 2313.0 in raw_data;
# i was looking for a mac which is portable and has all the features that i was looking for .
# sentence: 47.0 out of 2313.0 in raw_data;
# also kinda loud when the fan was running .
# sentence: 48.0 out of 2313.0 in raw_data;
# in desparation , i called their customer service number and was told that my warranty had expired ( 2 days old ) and that the priviledge of talking to a technician would cost me ( `` have your credit card ready '' ) .
# sentence: 49.0 out of 2313.0 in raw_data;
# in desparation , i called their customer service number and was told that my warranty had expired ( 2 days old ) and that the priviledge of talking to a technician would cost me ( `` have your credit card ready '' ) .
# sentence: 50.0 out of 2313.0 in raw_data;
# in desparation , i called their customer service number and was told that my warranty had expired ( 2 days old ) and that the priviledge of talking to a technician would cost me ( `` have your credit card ready '' ) .
# sentence: 51.0 out of 2313.0 in raw_data;
# there also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files .
# sentence: 52.0 out of 2313.0 in raw_data;
# there also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files .
# sentence: 53.0 out of 2313.0 in raw_data;
# there also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files .
# sentence: 54.0 out of 2313.0 in raw_data;
# drivers updated ok but the bios update froze the system up and the computer shut down .
# sentence: 55.0 out of 2313.0 in raw_data;
# drivers updated ok but the bios update froze the system up and the computer shut down .
# sentence: 56.0 out of 2313.0 in raw_data;
# drivers updated ok but the bios update froze the system up and the computer shut down .
# sentence: 57.0 out of 2313.0 in raw_data;
# spent 2 hours on phone with hp technical support .
# sentence: 58.0 out of 2313.0 in raw_data;
# speaking of the browser , it too has problems .
# sentence: 59.0 out of 2313.0 in raw_data;
# the keyboard is too slick .
# sentence: 60.0 out of 2313.0 in raw_data;
# nightly my computer defrags itself and runs a virus scan .
# sentence: 61.0 out of 2313.0 in raw_data;
# it 's like 9 punds , but if you can look past it , it 's great !
# sentence: 62.0 out of 2313.0 in raw_data;
# it 's just as fast with one program open as it is with sixteen open .
# sentence: 63.0 out of 2313.0 in raw_data;
# still under warrenty so called toshiba , no help at all .
# sentence: 64.0 out of 2313.0 in raw_data;
# i was happy with my purchase of a toshiba satellite l305d-s5934 laptop until it came time to have it repaired under the toshiba warranty .
# sentence: 65.0 out of 2313.0 in raw_data;
# amazing quality !
# sentence: 66.0 out of 2313.0 in raw_data;
# the fact that you can spend over $ 100 on just a webcam underscores the value of this machine .
# sentence: 67.0 out of 2313.0 in raw_data;
# the fact that you can spend over $ 100 on just a webcam underscores the value of this machine .
# sentence: 68.0 out of 2313.0 in raw_data;
# i mainly use it for email , internet , and managing personal files ( pics , vids , etc . ) .
# sentence: 69.0 out of 2313.0 in raw_data;
# i mainly use it for email , internet , and managing personal files ( pics , vids , etc . ) .
# sentence: 70.0 out of 2313.0 in raw_data;
# a month or so ago , the freaking motherboard just died .
# sentence: 71.0 out of 2313.0 in raw_data;
# the system it comes with does not work properly , so when trying to fix the problems with it it started not working at all .
# sentence: 72.0 out of 2313.0 in raw_data;
# then after 4 or so months the charger stopped working so i was forced to go out and buy new hardware just to keep this computer running .
# sentence: 73.0 out of 2313.0 in raw_data;
# then after 4 or so months the charger stopped working so i was forced to go out and buy new hardware just to keep this computer running .
# sentence: 74.0 out of 2313.0 in raw_data;
# if a website ever freezes ( which is rare ) , its really easy to force quit .
# sentence: 75.0 out of 2313.0 in raw_data;
# it rarely works and when it does it 's incredibly slow .
# sentence: 76.0 out of 2313.0 in raw_data;
# i also enjoy the fact that my macbook pro laptop allows me to run windows 7 on it by using the vmware program .
# sentence: 77.0 out of 2313.0 in raw_data;
# i also enjoy the fact that my macbook pro laptop allows me to run windows 7 on it by using the vmware program .
# sentence: 78.0 out of 2313.0 in raw_data;
# it 's so much easier to navigate through the operating system , to find files , and it runs a lot faster !
# sentence: 79.0 out of 2313.0 in raw_data;
# it 's so much easier to navigate through the operating system , to find files , and it runs a lot faster !
# sentence: 80.0 out of 2313.0 in raw_data;
# it 's so much easier to navigate through the operating system , to find files , and it runs a lot faster !
# sentence: 81.0 out of 2313.0 in raw_data;
# it 's so much easier to navigate through the operating system , to find files , and it runs a lot faster !
# sentence: 82.0 out of 2313.0 in raw_data;
# purchased a toshiba lap top it worked good until just after the warrenty went out .
# sentence: 83.0 out of 2313.0 in raw_data;
# i wanted to purchase the extended warranty and they refused , because they knew it was trouble .
# sentence: 84.0 out of 2313.0 in raw_data;
# we upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed .
# sentence: 85.0 out of 2313.0 in raw_data;
# we upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed .
# sentence: 86.0 out of 2313.0 in raw_data;
# we upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed .
# sentence: 87.0 out of 2313.0 in raw_data;
# the reality was , it heated up very quickly , and took way too long to do simple things , like opening my documents folder .
# sentence: 88.0 out of 2313.0 in raw_data;
# i had always used pcs and been constantly frustrated by the crashing and the poorly designed operating systems that were never very intuitive .
# sentence: 89.0 out of 2313.0 in raw_data;
# then , within 5 months , the charger crapped out on me .
# sentence: 90.0 out of 2313.0 in raw_data;
# and if you have a iphone or ipod touch you can connect and download songs to it at high speed .
# sentence: 91.0 out of 2313.0 in raw_data;
# i love the glass touchpad .
# sentence: 92.0 out of 2313.0 in raw_data;
# i continued to take the computer in again and they replaced the hard drive and mother board yet again .
# sentence: 93.0 out of 2313.0 in raw_data;
# i continued to take the computer in again and they replaced the hard drive and mother board yet again .
# sentence: 94.0 out of 2313.0 in raw_data;
# i am using the $t$- sound is good . external speaker
# sentence: 95.0 out of 2313.0 in raw_data;
# i am using the external speaker- sound is good .
# sentence: 96.0 out of 2313.0 in raw_data;
# still testing the battery life as i thought it would be better , but am very happy with the upgrade .
# sentence: 97.0 out of 2313.0 in raw_data;
# then hp sends it back to me with the hardware screwed up , not able to connect .
# sentence: 98.0 out of 2313.0 in raw_data;
# oh yeah , do n't forget the expensive shipping to and from hp .
# sentence: 99.0 out of 2313.0 in raw_data;
# everything is so easy to use , mac software is just so much simpler than microsoft software .
# sentence: 100.0 out of 2313.0 in raw_data;
# everything is so easy to use , mac software is just so much simpler than microsoft software .
# sentence: 101.0 out of 2313.0 in raw_data;
# everything is so easy to use , mac software is just so much simpler than microsoft software .
# sentence: 102.0 out of 2313.0 in raw_data;
# and if you do a lot of writing , editing is a problem since there is no forward delete key .
# sentence: 103.0 out of 2313.0 in raw_data;
# and if you do a lot of writing , editing is a problem since there is no forward delete key .
# sentence: 104.0 out of 2313.0 in raw_data;
# its ease of use and the top service from apple- be it their phone assistance or bellying up to the genius bar- can not be beat .
# sentence: 105.0 out of 2313.0 in raw_data;
# its ease of use and the top service from apple- be it their phone assistance or bellying up to the genius bar- can not be beat .
# sentence: 106.0 out of 2313.0 in raw_data;
# its ease of use and the top service from apple- be it their phone assistance or bellying up to the genius bar- can not be beat .
# sentence: 107.0 out of 2313.0 in raw_data;
# its ease of use and the top service from apple- be it their phone assistance or bellying up to the $t$- can not be beat . genius bar
# sentence: 108.0 out of 2313.0 in raw_data;
# it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a of just over 5 hours .
# sentence: 109.0 out of 2313.0 in raw_data;
# it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a of just over 5 hours .
# sentence: 110.0 out of 2313.0 in raw_data;
# it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# sentence: 111.0 out of 2313.0 in raw_data;
# it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# sentence: 112.0 out of 2313.0 in raw_data;
# it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# sentence: 113.0 out of 2313.0 in raw_data;
# it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# sentence: 114.0 out of 2313.0 in raw_data;
# acer has set me up with free recovery discs , when they are available since i asked .
# sentence: 115.0 out of 2313.0 in raw_data;
# i also purchased office max 's `` max assurance '' with the `` no lemon '' clause .
# sentence: 116.0 out of 2313.0 in raw_data;
# i eventually did the migration from my imac backup disc which uses usb .
# sentence: 117.0 out of 2313.0 in raw_data;
# i eventually did the migration from my imac backup disc which uses usb .
# sentence: 118.0 out of 2313.0 in raw_data;
# the battery life seems to be very good , and have had no issues with it .
# sentence: 119.0 out of 2313.0 in raw_data;
# enabling the battery timer is useless .
# sentence: 120.0 out of 2313.0 in raw_data;
# temperatures on the outside were alright but i did not track in core processing unit .
# sentence: 121.0 out of 2313.0 in raw_data;
# temperatures on the outside were alright but i did not track in core processing unit temperatures .
# sentence: 122.0 out of 2313.0 in raw_data;
# going to bring it to service today .
# sentence: 123.0 out of 2313.0 in raw_data;
# there is no need to purchase virus protection for mac , which saves me a lot of time and money .
# sentence: 124.0 out of 2313.0 in raw_data;
# but we had paid for bluetooth , and there was none .
# sentence: 125.0 out of 2313.0 in raw_data;
# so , i paid a visit to lg notebook service center at alexandra road , hoping they can make the hinge tighter .
# sentence: 126.0 out of 2313.0 in raw_data;
# so , i paid a visit to lg notebook service center at alexandra road , hoping they can make the hinge tighter .
# sentence: 127.0 out of 2313.0 in raw_data;
# my daughter uses it for games , email , facebook , pictures and music .
# sentence: 128.0 out of 2313.0 in raw_data;
# it is always reliable , never bugged and responds well .
# sentence: 129.0 out of 2313.0 in raw_data;
# after about a week i finally got it back and was told that the motherboard had failed and so they installed a new .
# sentence: 130.0 out of 2313.0 in raw_data;
# after about a week i finally got it back and was told that the motherboard had failed and so they installed a new .
# sentence: 131.0 out of 2313.0 in raw_data;
# it was slow , locked up , and also had hardware replaced after only 2 months !
# sentence: 132.0 out of 2313.0 in raw_data;
# they had to replace the motherboard in april
# sentence: 133.0 out of 2313.0 in raw_data;
# yes , the computer was light weight , less expensive than the average laptop , and was pretty self explantory in use .
# sentence: 134.0 out of 2313.0 in raw_data;
# also , if you need to talk to a representive at microsoft , there is a charge , which i believe is robbery , since you are charged enormous amounts for a very badly designed system , which most people would have went with xp if they could .
# sentence: 135.0 out of 2313.0 in raw_data;
# also , if you need to talk to a representive at microsoft , there is a charge , which i believe is robbery , since you are charged enormous amounts for a very badly designed system , which most people would have went with xp if they could .
# sentence: 136.0 out of 2313.0 in raw_data;
# also , if you need to talk to a representive at microsoft , there is a charge , which i believe is robbery , since you are charged enormous amounts for a very badly designed system , which most people would have went with xp if they could .
# sentence: 137.0 out of 2313.0 in raw_data;
# i love windows 7 which is a vast improvment over vista .
# sentence: 138.0 out of 2313.0 in raw_data;
# i love windows 7 which is a vast improvment over vista .
# sentence: 139.0 out of 2313.0 in raw_data;
# keyboard is great , very quiet for all the typing that i do .
# sentence: 140.0 out of 2313.0 in raw_data;
# dell 's customer disservice is an insult to it 's customers who pay good money for shoddy products .
# sentence: 141.0 out of 2313.0 in raw_data;
# it had a cooling system malfunction after 10 minutes of general use , and would not move past this error .
# sentence: 142.0 out of 2313.0 in raw_data;
# it had a cooling system malfunction after 10 minutes of general use , and would not move past this error .
# sentence: 143.0 out of 2313.0 in raw_data;
# i can render avchd movies with little effort , which was a problem for most pc 's unless you had a quad core i7 .
# sentence: 144.0 out of 2313.0 in raw_data;
# after talking it over with the very knowledgeable sales associate , i chose the macbook pro over the white macbook .
# sentence: 145.0 out of 2313.0 in raw_data;
# if you really want a bang-up system and do n't need to run windows applications , go with an apple ;
# sentence: 146.0 out of 2313.0 in raw_data;
# if you really want a bang-up system and do n't need to run windows applications , go with an apple ;
# sentence: 147.0 out of 2313.0 in raw_data;
# you wo n't have to spend gobs of money on some inefficient virus program that needs to be updated every month and that constantly drains your wallet .
# sentence: 148.0 out of 2313.0 in raw_data;
# it weighed like seven pounds or something like that .
# sentence: 149.0 out of 2313.0 in raw_data;
# it weighed like seven pounds or something like that .
# sentence: 150.0 out of 2313.0 in raw_data;
# 2 months later , the battery went .
# sentence: 151.0 out of 2313.0 in raw_data;
# you may need to special order a bag .
# sentence: 152.0 out of 2313.0 in raw_data;
# it 's color is even cool .
# sentence: 153.0 out of 2313.0 in raw_data;
# keys are all in weird places and is way too large for the way it is designed .
# sentence: 154.0 out of 2313.0 in raw_data;
# keys are all in weird places and is way too large for the way it is designed .
# sentence: 155.0 out of 2313.0 in raw_data;
# yes , a mac is much more money than the average laptop out there , but there is no comparison in style , speed and just cool factor .
# sentence: 156.0 out of 2313.0 in raw_data;
# yes , a mac is much more money than the average laptop out there , but there is no comparison in style , speed and just cool factor .
# sentence: 157.0 out of 2313.0 in raw_data;
# the keyboard feels good and i type just fine on it .
# sentence: 158.0 out of 2313.0 in raw_data;
# i thought the white mac computers looked dirty too quicly where you use the mousepad and where you place your hands when typing .
# sentence: 159.0 out of 2313.0 in raw_data;
# and not to mention after using it for a few months or so , the battery will slowly less and less hold a charge until you ca n't leave it unplugged for more than 5 minutes without the thing dying .
# sentence: 160.0 out of 2313.0 in raw_data;
# best buy - 5 stars + + + ( sales , service , respect for old men who are n't familiar with the technology ) dell computers - 3 stars dell support - owes a me a couple
# sentence: 161.0 out of 2313.0 in raw_data;
# best buy - 5 stars + + + ( sales , service , respect for old men who are n't familiar with the technology ) dell computers - 3 stars dell support - owes a me a couple
# sentence: 162.0 out of 2313.0 in raw_data;
# best buy - 5 stars + + + ( sales , service , respect for old men who are n't familiar with the technology ) dell computers - 3 stars dell support - owes a me a couple
# sentence: 163.0 out of 2313.0 in raw_data;
# no complaints with their desktop , and maybe because it just sits on your desktop , and you do n't carry it around , which could jar the hard drive , or the motherboard .
# sentence: 164.0 out of 2313.0 in raw_data;
# no complaints with their desktop , and maybe because it just sits on your desktop , and you do n't carry it around , which could jar the hard drive , or the motherboard .
# sentence: 165.0 out of 2313.0 in raw_data;
# yes , they cost more , but they more than make up for it in speed , construction quality , and longevity .
# sentence: 166.0 out of 2313.0 in raw_data;
# yes , they cost more , but they more than make up for it in speed , construction quality , and longevity .
# sentence: 167.0 out of 2313.0 in raw_data;
# yes , they cost more , but they more than make up for it in speed , construction quality , and longevity .
# sentence: 168.0 out of 2313.0 in raw_data;
# since i keyboard over 100 wpm , i look for a unit that has a comfortble ( no keys sticking or lagging , strange configuration of `` extra key '' , etc .
# sentence: 169.0 out of 2313.0 in raw_data;
# since i keyboard over 100 wpm , i look for a unit that has a comfortble keyboard ( no keys sticking or lagging , strange configuration of `` extra key '' , etc .
# sentence: 170.0 out of 2313.0 in raw_data;
# since i keyboard over 100 wpm , i look for a unit that has a comfortble keyboard ( no keys sticking or lagging , strange configuration of `` extra key '' , etc .
# sentence: 171.0 out of 2313.0 in raw_data;
# ) i also tried the touch pad and compared it to other netbooks in the store .
# sentence: 172.0 out of 2313.0 in raw_data;
# it absolutely is more expensive than most pc laptops , but the ease of use , security , and minimal problems that have arisen make it well worth the pricetag .
# sentence: 173.0 out of 2313.0 in raw_data;
# it absolutely is more expensive than most pc laptops , but the ease of use , security , and minimal problems that have arisen make it well worth the pricetag .
# sentence: 174.0 out of 2313.0 in raw_data;
# it gets stuck all of the time you use it , and you have to keep tapping on it to get it to work .
# sentence: 175.0 out of 2313.0 in raw_data;
# it gets stuck all of the time you use it , and you have to keep tapping on it to get it to work .
# sentence: 176.0 out of 2313.0 in raw_data;
# lots of preloaded software .
# sentence: 177.0 out of 2313.0 in raw_data;
# i wish it had a webcam though , then it would be perfect !
# sentence: 178.0 out of 2313.0 in raw_data;
# my favorite part of this computer is that it has a vga port so i can connect it to a bigger screen .
# sentence: 179.0 out of 2313.0 in raw_data;
# my favorite part of this computer is that it has a vga port so i can connect it to a bigger screen .
# sentence: 180.0 out of 2313.0 in raw_data;
# another thing i might add is the battery life is excellent .
# sentence: 181.0 out of 2313.0 in raw_data;
# one drawback , i wish the keys were backlit .
# sentence: 182.0 out of 2313.0 in raw_data;
# acer was no help and garmin could not determine the problem ( after spending about 2 hours with me ) , so i returned it and purchased a toshiba r700 that seems even nicer and i was able to load all of my software with no problem .
# sentence: 183.0 out of 2313.0 in raw_data;
# i wish the volume could be louder and the mouse didnt break after only a month .
# sentence: 184.0 out of 2313.0 in raw_data;
# i wish the volume could be louder and the mouse didnt break after only a month .
# sentence: 185.0 out of 2313.0 in raw_data;
# i play a lot of casual games online , and the touchpad is very responsive .
# sentence: 186.0 out of 2313.0 in raw_data;
# granted , it 's still a very new laptop but in comparison to my previous laptops and desktops , my mac boots up noticeably quicker .
# sentence: 187.0 out of 2313.0 in raw_data;
# it caught a virus that completely wiped out my hard drive in a matter of hours .
# sentence: 188.0 out of 2313.0 in raw_data;
# it is everything i 'd hoped it would be from a look and feel standpoint , but somehow a bit more sturdy .
# sentence: 189.0 out of 2313.0 in raw_data;
# the only fact i dont like about apples is they generally use safari and i dont use but after i install mozzilla firfox i love every single bit about it .
# sentence: 190.0 out of 2313.0 in raw_data;
# the only fact i dont like about apples is they generally use safari and i dont use but after i install mozzilla firfox i love every single bit about it .
# sentence: 191.0 out of 2313.0 in raw_data;
# the only fact i dont like about apples is they generally use safari and i dont use safari but after i install mozzilla firfox i love every single bit about it .
# sentence: 192.0 out of 2313.0 in raw_data;
# the bluetooth was not there at all , and the fingerprint reader driver would be there , but the software would hang after installation was 1/2 way done .
# sentence: 193.0 out of 2313.0 in raw_data;
# the bluetooth was not there at all , and the fingerprint reader driver would be there , but the software would hang after installation was 1/2 way done .
# sentence: 194.0 out of 2313.0 in raw_data;
# the bluetooth was not there at all , and the fingerprint reader driver would be there , but the software would hang after installation was 1/2 way done .
# sentence: 195.0 out of 2313.0 in raw_data;
# great battery , speed , display .
# sentence: 196.0 out of 2313.0 in raw_data;
# great battery , speed , display .
# sentence: 197.0 out of 2313.0 in raw_data;
# great battery , speed , display .
# sentence: 198.0 out of 2313.0 in raw_data;
# the delivery was fast , and i would not hesitate to purchase this laptop again .
# sentence: 199.0 out of 2313.0 in raw_data;
# i 've been impressed with the battery life and the performance for such a small amount of memory .
# sentence: 200.0 out of 2313.0 in raw_data;
# i 've been impressed with the battery life and the performance for such a small amount of memory .
# sentence: 201.0 out of 2313.0 in raw_data;
# i 've been impressed with the battery life and the performance for such a small amount of memory .
# sentence: 202.0 out of 2313.0 in raw_data;
# it 's applications are terrific , including the replacements for microsoft office .
# sentence: 203.0 out of 2313.0 in raw_data;
# it 's applications are terrific , including the replacements for microsoft office .
# sentence: 204.0 out of 2313.0 in raw_data;
# they improved nothing else such as resolution , appearance , cooling system , graphics card , etc .
# sentence: 205.0 out of 2313.0 in raw_data;
# they improved nothing else such as resolution , appearance , cooling system , graphics card , etc .
# sentence: 206.0 out of 2313.0 in raw_data;
# they improved nothing else such as resolution , appearance , cooling system , graphics card , etc .
# sentence: 207.0 out of 2313.0 in raw_data;
# they improved nothing else such as resolution , appearance , cooling system , graphics card , etc .
# sentence: 208.0 out of 2313.0 in raw_data;
# i got it back and my built-in webcam and built-in mic were shorting out anytime i touched the lid , ( mind you this was my means of communication with my fiance who was deployed ) but i suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out .
# sentence: 209.0 out of 2313.0 in raw_data;
# i got it back and my built-in webcam and built-in mic were shorting out anytime i touched the lid , ( mind you this was my means of communication with my fiance who was deployed ) but i suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out .
# sentence: 210.0 out of 2313.0 in raw_data;
# i got it back and my built-in web$t$ and built-in mic were shorting out anytime i touched the lid , ( mind you this was my means of communication with my fiance who was deployed ) but i suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out .
# sentence: 211.0 out of 2313.0 in raw_data;
# i got it back and my built-in webcam and built-in mic were shorting out anytime i touched the lid , ( mind you this was my means of communication with my fiance who was deployed ) but i suffered thru it and would constandly have to reset the computer to be able to use my cam and anytime they went out .
# sentence: 212.0 out of 2313.0 in raw_data;
# is this partially due to the fact that it is running windows vista ?
# sentence: 213.0 out of 2313.0 in raw_data;
# the board has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues .
# sentence: 214.0 out of 2313.0 in raw_data;
# the board has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues .
# sentence: 215.0 out of 2313.0 in raw_data;
# the board has a bad connector with the power supply and shortly after warrenty expires the will start having issues .
# sentence: 216.0 out of 2313.0 in raw_data;
# the board has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues .
# sentence: 217.0 out of 2313.0 in raw_data;
# the board has a bad connector with the power supply and shortly after warrenty expires the will start having issues .
# sentence: 218.0 out of 2313.0 in raw_data;
# my dad has one of the very first toshibas ever made , yes its abit slow now but still works well and i hooked to my ethernet !
# sentence: 219.0 out of 2313.0 in raw_data;
# my dad has one of the very first toshibas ever made , yes its abit slow now but still works well and i hooked to my ethernet !
# sentence: 220.0 out of 2313.0 in raw_data;
# mostly i love the drag and drop feature .
# sentence: 221.0 out of 2313.0 in raw_data;
# oh yeah , and if the fancy webcam breaks guess who you have to send it to to get it fixed ?
# sentence: 222.0 out of 2313.0 in raw_data;
# i ordered through macmall , which saved me the sales tax i would have incurred buying locally .
# sentence: 223.0 out of 2313.0 in raw_data;
# of course , i also have several great software packages that came for free including iwork , garageband , and imovie .
# sentence: 224.0 out of 2313.0 in raw_data;
# of course , i also have several great software packages that came for free including iwork , garageband , and imovie .
# sentence: 225.0 out of 2313.0 in raw_data;
# of course , i also have several great software packages that came for free including iwork , garageband , and imovie .
# sentence: 226.0 out of 2313.0 in raw_data;
# of course , i also have several great software packages that came for free including iwork , garageband , and imovie .
# sentence: 227.0 out of 2313.0 in raw_data;
# the screen is very large and crystal clear with amazing colors and resolution .
# sentence: 228.0 out of 2313.0 in raw_data;
# the screen is very large and crystal clear with amazing colors and resolution .
# sentence: 229.0 out of 2313.0 in raw_data;
# the screen is very large and crystal clear with amazing colors and resolution .
# sentence: 230.0 out of 2313.0 in raw_data;
# after a little more than a year of owning my macbook pro , the monitor has completely died .
# sentence: 231.0 out of 2313.0 in raw_data;
# the brand of itunes has just become ingrained in our lexicon now , but keep in mind that apple started it all .
# sentence: 232.0 out of 2313.0 in raw_data;
# size : i know 13 is small ( especially for a desktop replacement ) but with an external monitor , who cares .
# sentence: 233.0 out of 2313.0 in raw_data;
# size : i know 13 is small ( especially for a desktop replacement ) but with an external monitor , who cares .
# sentence: 234.0 out of 2313.0 in raw_data;
# additional caveat : the base installation comes with some toshiba-specific software that may or may not be to a user 's liking .
# sentence: 235.0 out of 2313.0 in raw_data;
# additional caveat : the base installation comes with some toshiba-specific software that may or may not be to a user 's liking .
# sentence: 236.0 out of 2313.0 in raw_data;
# taking it back to best buy i found that a tiny plastic piece inside had broken ( manuf issue ) .
# sentence: 237.0 out of 2313.0 in raw_data;
# the display is incredibly bright , much brighter than my powerbook and very crisp .
# sentence: 238.0 out of 2313.0 in raw_data;
# the amd turin processor seems to always perform so much better than intel .
# sentence: 239.0 out of 2313.0 in raw_data;
# the amd turin processor seems to always perform so much better than intel .
# sentence: 240.0 out of 2313.0 in raw_data;
# after that the said it was under warranty .
# sentence: 241.0 out of 2313.0 in raw_data;
# the start menu is not the easiest thing to navigate due to the stacking .
# sentence: 242.0 out of 2313.0 in raw_data;
# the start menu is not the easiest thing to navigate due to the stacking .
# sentence: 243.0 out of 2313.0 in raw_data;
# only thing i would want to add to this is an internal bluray read/write drive .
# sentence: 244.0 out of 2313.0 in raw_data;
# the service tech said he had tried to duplicate the damage and was n't able to recreate it therefore it had to be their defect .
# sentence: 245.0 out of 2313.0 in raw_data;
# the tech store i purchased this from sent it back , , , , , eventually i got a new or repaired machine approximately 3 weeks later .
# sentence: 246.0 out of 2313.0 in raw_data;
# really like the textured surface which shows no fingerprints .
# sentence: 247.0 out of 2313.0 in raw_data;
# the screen is bright and the keyboard is nice ;
# sentence: 248.0 out of 2313.0 in raw_data;
# the screen is bright and the keyboard is nice ;
# sentence: 249.0 out of 2313.0 in raw_data;
# but the machine is awesome and ilife is great and i love snow leopard x .
# sentence: 250.0 out of 2313.0 in raw_data;
# but the machine is awesome and ilife is great and i love snow leopard x .
# sentence: 251.0 out of 2313.0 in raw_data;
# high price tag , however .
# sentence: 252.0 out of 2313.0 in raw_data;
# i thought learning the mac os would be hard , but it is easily picked up if you are familiar with a pc .
# sentence: 253.0 out of 2313.0 in raw_data;
# i had static in the output , and i had to reduce the sound output quality to `` fm '' as opposed to the default `` cd .
# sentence: 254.0 out of 2313.0 in raw_data;
# i custom ordered the machine from hp and could not understand the techie due to his accent .
# sentence: 255.0 out of 2313.0 in raw_data;
# it is easy to use and lightweight .
# sentence: 256.0 out of 2313.0 in raw_data;
# i went to toshiba online help and found some suggestions to fix it .
# sentence: 257.0 out of 2313.0 in raw_data;
# they also have a longer service life than other computers ( i have several friends who still use the older apple powerbooks ) .
# sentence: 258.0 out of 2313.0 in raw_data;
# if you check you will find the same notebook with the above missing ports and a dual core amd or intel processor .
# sentence: 259.0 out of 2313.0 in raw_data;
# if you check you will find the same notebook with the above missing ports and a dual core amd or intel processor .
# sentence: 260.0 out of 2313.0 in raw_data;
# this laptop is a great price and has a sleek look .
# sentence: 261.0 out of 2313.0 in raw_data;
# this laptop is a great price and has a sleek look .
# sentence: 262.0 out of 2313.0 in raw_data;
# i especially like the keyboard which has chiclet type keys .
# sentence: 263.0 out of 2313.0 in raw_data;
# i especially like the keyboard which has chiclet type keys .
# sentence: 264.0 out of 2313.0 in raw_data;
# runs hot i thought we were paying for quality in our decision to buy an apple product .
# sentence: 265.0 out of 2313.0 in raw_data;
# for the not so good , i got the stock screen - which is very glossy .
# sentence: 266.0 out of 2313.0 in raw_data;
# the gray color was a good choice .
# sentence: 267.0 out of 2313.0 in raw_data;
# i would like to have volume buttons rather than the adjustment that is on the front .
# sentence: 268.0 out of 2313.0 in raw_data;
# the processor a amd semprom at 2.1 ghz is a bummer it does not have the power for hd or heavy computing .
# sentence: 269.0 out of 2313.0 in raw_data;
# the processor a amd semprom at 2.1 ghz is a bummer it does not have the power for hd or heavy computing .
# sentence: 270.0 out of 2313.0 in raw_data;
# i bought a protector for my key pad and it works great : )
# sentence: 271.0 out of 2313.0 in raw_data;
# i bought a protector for my key pad and it works great : )
# sentence: 272.0 out of 2313.0 in raw_data;
# the magnetic plug-in power charging power cord is great ( i even put it to the test by accident ) - excellent innovation !
# sentence: 273.0 out of 2313.0 in raw_data;
# it seems they could have updated xp and done without creating vista .
# sentence: 274.0 out of 2313.0 in raw_data;
# it seems they could have updated xp and done without creating vista .
# sentence: 275.0 out of 2313.0 in raw_data;
# it is easy to use , fast and has great graphics for the money .
# sentence: 276.0 out of 2313.0 in raw_data;
# it is easy to use , fast and has great graphics for the money .
# sentence: 277.0 out of 2313.0 in raw_data;
# i like how the mac os is so simple and easy to use .
# sentence: 278.0 out of 2313.0 in raw_data;
# i like how the mac os is so simple and easy to use .
# sentence: 279.0 out of 2313.0 in raw_data;
# while apple 's saving grace is the fact that they at least stand behind their products , and their support is great , it would be nice if their products were more reliable to justify the premium .
# sentence: 280.0 out of 2313.0 in raw_data;
# i was ready to take it back for a refund , but the geek squad camed through and pointed me in the right direction to get it fixed .
# sentence: 281.0 out of 2313.0 in raw_data;
# only good thing is the graphics quality .
# sentence: 282.0 out of 2313.0 in raw_data;
# the other lock-up problems are from a myriad of causes , the most common being a corrupted version of appleworks which can render the browser useless .
# sentence: 283.0 out of 2313.0 in raw_data;
# the other lock-up problems are from a myriad of causes , the most common being a corrupted version of appleworks which can render the browser useless .
# sentence: 284.0 out of 2313.0 in raw_data;
# the paint wears off easily due to the keyboard being farther back than usual .
# sentence: 285.0 out of 2313.0 in raw_data;
# the paint wears off easily due to the keyboard being farther back than usual .
# sentence: 286.0 out of 2313.0 in raw_data;
# i had purchased it from a major electronics store and took it to their service department to find out what the problem was .
# sentence: 287.0 out of 2313.0 in raw_data;
# the store honored their warrenty and made the comment that they do n't even recommend the hp brand because of the problems with their $t$s .
# sentence: 288.0 out of 2313.0 in raw_data;
# the store honored their warrenty and made the comment that they do n't even recommend the hp brand because of the problems with their warrentys .
# sentence: 289.0 out of 2313.0 in raw_data;
# i always use a backup hard disk to store important files at all times .
# sentence: 290.0 out of 2313.0 in raw_data;
# they sent out the box right away for me to send in my computer , they paid postage and whatnot , but when i got my computer back it still was n't running right , and now my cd drive was n't reading anything !
# sentence: 291.0 out of 2313.0 in raw_data;
# they sent out the box right away for me to send in my computer , they paid postage and whatnot , but when i got my computer back it still was n't running right , and now my cd drive was n't reading anything !
# sentence: 292.0 out of 2313.0 in raw_data;
# but the screen size is not that bad for email and web browsing .
# sentence: 293.0 out of 2313.0 in raw_data;
# but the screen size is not that bad for email and web browsing .
# sentence: 294.0 out of 2313.0 in raw_data;
# once i removed all the software the laptop loads in 15-20 seconds .
# sentence: 295.0 out of 2313.0 in raw_data;
# once i removed all the software the laptop loads in 15-20 seconds .
# sentence: 296.0 out of 2313.0 in raw_data;
# on my powerbook g4 i would never use the trackpad i would use an external mouse because i did n't like the .
# sentence: 297.0 out of 2313.0 in raw_data;
# on my powerbook g4 i would never use the trackpad i would use an external mouse because i did n't like the trackpad .
# sentence: 298.0 out of 2313.0 in raw_data;
# on my powerbook g4 i would never use the trackpad i would use an external mouse because i did n't like the .
# sentence: 299.0 out of 2313.0 in raw_data;
# this computer does n't do that well with certain games it ca n't play some and it becomes too hot while playing .
# sentence: 300.0 out of 2313.0 in raw_data;
# obviously one of the most important features of any computer is the `` human interface .
# sentence: 301.0 out of 2313.0 in raw_data;
# obviously one of the most important features of any computer is the `` human interface .
# sentence: 302.0 out of 2313.0 in raw_data;
# yeah , of course smarty pants `` fix it now '' ) software - compared to the early 2011 edition i did see inbuilt applications crashing and it prompted me to send the report to apple ( which i promptly did ) .
# sentence: 303.0 out of 2313.0 in raw_data;
# yeah , of course smarty pants `` fix it now '' ) software - compared to the early 2011 edition i did see inbuilt applications crashing and it prompted me to send the report to apple ( which i promptly did ) .
# sentence: 304.0 out of 2313.0 in raw_data;
# the body is a bit cheaply made so it will be interesting to see how long it holds up .
# sentence: 305.0 out of 2313.0 in raw_data;
# the i5 blows my desktop out of the water when it comes to rendering videos .
# sentence: 306.0 out of 2313.0 in raw_data;
# with a mac you do n't have to worry about antivirus software or firewall , it 's so wonderful .
# sentence: 307.0 out of 2313.0 in raw_data;
# with a mac you do n't have to worry about antivirus software or firewall , it 's so wonderful .
# sentence: 308.0 out of 2313.0 in raw_data;
# am very glad i bought it , great netbook , low price .
# sentence: 309.0 out of 2313.0 in raw_data;
# the apple team also assists you very nicely when choosing which computer is right for you : )
# sentence: 310.0 out of 2313.0 in raw_data;
# i think part of the problem with this computer is vista , yet i know is n't the entire issue because my latest purchase was my acer and it also has ( i should have waited the few months to get the next operating system ) .
# sentence: 311.0 out of 2313.0 in raw_data;
# i think part of the problem with this computer is vista , yet i know is n't the entire issue because my latest purchase was my acer and it also has ( i should have waited the few months to get the next operating system ) .
# sentence: 312.0 out of 2313.0 in raw_data;
# i think part of the problem with this computer is vista , yet i know vista is n't the entire issue because my latest purchase was my acer and it also has vista ( i should have waited the few months to get the next operating system ) .
# sentence: 313.0 out of 2313.0 in raw_data;
# i think part of the problem with this computer is vista , yet i know is n't the entire issue because my latest purchase was my acer and it also has ( i should have waited the few months to get the next operating system ) .
# sentence: 314.0 out of 2313.0 in raw_data;
# ...
# sentence: 2205.0 out of 2313.0 in raw_data;
# i am not sure if it was the drive itself , however ;
# sentence: 2206.0 out of 2313.0 in raw_data;
# also , one of the users mentioned how the edges on the macbook is sharp , if you have money to spend on one of the incase shells , it does n't seem to be a problem .
# sentence: 2207.0 out of 2313.0 in raw_data;
# also , one of the users mentioned how the edges on the macbook is sharp , if you have money to spend on one of the incase shells , it does n't seem to be a problem .
# sentence: 2208.0 out of 2313.0 in raw_data;
# it is easy to use , its keyboard easily accommodates large hands , and its weight is fantasic .
# sentence: 2209.0 out of 2313.0 in raw_data;
# it is easy to use , its keyboard easily accommodates large hands , and its weight is fantasic .
# sentence: 2210.0 out of 2313.0 in raw_data;
# it is easy to use , its keyboard easily accommodates large hands , and its weight is fantasic .
# sentence: 2211.0 out of 2313.0 in raw_data;
# called acer many times , they want me to pay the shipping to ship it to their repair center - i was very disappointed since it is a brand new computer !
# sentence: 2212.0 out of 2313.0 in raw_data;
# called acer many times , they want me to pay the shipping to ship it to their repair center - i was very disappointed since it is a brand new computer !
# sentence: 2213.0 out of 2313.0 in raw_data;
# i should have checked this before i installed my applications .
# sentence: 2214.0 out of 2313.0 in raw_data;
# the battery is really long .
# sentence: 2215.0 out of 2313.0 in raw_data;
# anyway , in early july of this year , the dvd burner stopped working , and the computer stared having issues with power supply .
# sentence: 2216.0 out of 2313.0 in raw_data;
# anyway , in early july of this year , the dvd burner stopped working , and the computer stared having issues with power supply .
# sentence: 2217.0 out of 2313.0 in raw_data;
# had some trouble finding a case that it would fit in .
# sentence: 2218.0 out of 2313.0 in raw_data;
# this computer that i have has had issues with the keyboard where it lost half the functions .
# sentence: 2219.0 out of 2313.0 in raw_data;
# this computer that i have has had issues with the keyboard where it lost half the keyboard functions .
# sentence: 2220.0 out of 2313.0 in raw_data;
# comes with imovie ;
# sentence: 2221.0 out of 2313.0 in raw_data;
# computer has been at service facility more than in my hands .
# sentence: 2222.0 out of 2313.0 in raw_data;
# when i called sony the customer service was great .
# sentence: 2223.0 out of 2313.0 in raw_data;
# even though i had the receipt in front of me proving it still had 2 months left on the warranty .
# sentence: 2224.0 out of 2313.0 in raw_data;
# it is a much more streamlined system for adding programs , using the internet , and doing other things everyone does on a computer .
# sentence: 2225.0 out of 2313.0 in raw_data;
# it is a much more streamlined system for adding programs , using the internet , and doing other things everyone does on a computer .
# sentence: 2226.0 out of 2313.0 in raw_data;
# it is a much more streamlined system for adding programs , using the internet , and doing other things everyone does on a computer .
# sentence: 2227.0 out of 2313.0 in raw_data;
# my computer froze on several occasion , had buttons that randomely would fall off and even had moments when the computer would refuse to turn on at all .
# sentence: 2228.0 out of 2313.0 in raw_data;
# not even safe mode boots .
# sentence: 2229.0 out of 2313.0 in raw_data;
# this is an over-sized , 18-inch laptop .
# sentence: 2230.0 out of 2313.0 in raw_data;
# i had to pay $ 100 for a universal charger for this cheap $ 300 laptop .
# sentence: 2231.0 out of 2313.0 in raw_data;
# the powerpoint opened seamlessly in the apple and the mac hooked up to the projector so easily it was almost scary .
# sentence: 2232.0 out of 2313.0 in raw_data;
# 1.you can not change your desktop background ( window 's 7 starter does not support that function ) .
# sentence: 2233.0 out of 2313.0 in raw_data;
# 1.you can not change your desktop background ( window 's 7 starter does not support that function ) .
# sentence: 2234.0 out of 2313.0 in raw_data;
# 1.you can not change your desktop background ( window 's 7 starter does not support that function ) .
# sentence: 2235.0 out of 2313.0 in raw_data;
# took me 11 hours , 3 trips to different fedex offices , and brutal conversations with 14 of the worse it support technicians in the world .
# sentence: 2236.0 out of 2313.0 in raw_data;
# then after 4 or so months the charger stopped working so i was forced to go out and buy new hardware just to keep this computer running .
# sentence: 2237.0 out of 2313.0 in raw_data;
# then after 4 or so months the charger stopped working so i was forced to go out and buy new hardware just to keep this computer running .
# sentence: 2238.0 out of 2313.0 in raw_data;
# as usual at customer service center , she asked me to hold for a moment while she went to the back-office and compare it with other same model netbooks and discussed it with her colleague ( i could see them ) .
# sentence: 2239.0 out of 2313.0 in raw_data;
# the screen gets smeary and dusty very quickly and it 's very noticeable .
# sentence: 2240.0 out of 2313.0 in raw_data;
# strengths : well-shaped weaknesses : a bad videocard !
# sentence: 2241.0 out of 2313.0 in raw_data;
# strengths : well-$t$ weaknesses : a bad videocard ! shaped
# sentence: 2242.0 out of 2313.0 in raw_data;
# you ca n't even get a satellite card which is why i bought to begin with .
# sentence: 2243.0 out of 2313.0 in raw_data;
# the battery life , before the battery completely died of course , left much to be desired .
# sentence: 2244.0 out of 2313.0 in raw_data;
# the battery life , before the completely died of course , left much to be desired .
# sentence: 2245.0 out of 2313.0 in raw_data;
# it is a real touchpad , not the toy i saw in other brands .
# sentence: 2246.0 out of 2313.0 in raw_data;
# long story , but after many calls to various offices , i was told that no one can override the depot and that managers do n't take phone calls or e/mails .
# sentence: 2247.0 out of 2313.0 in raw_data;
# price and purpose is awesome !
# sentence: 2248.0 out of 2313.0 in raw_data;
# wonderful zooming .
# sentence: 2249.0 out of 2313.0 in raw_data;
# the screen is huge and coloful , but no led backlighting .
# sentence: 2250.0 out of 2313.0 in raw_data;
# in all honesty , if someone is looking for a quality laptop and willing to pay a little more money for a normal sized laptop than a cheaper and less impressive laptop , then do not buy this computer .
# sentence: 2251.0 out of 2313.0 in raw_data;
# everything about this computer is easy to use .
# sentence: 2252.0 out of 2313.0 in raw_data;
# worse , for the price i could get a *netbook* that outperforms this machine .
# sentence: 2253.0 out of 2313.0 in raw_data;
# it had most of the features and all of the power that i wanted to replace my desktop machine .
# sentence: 2254.0 out of 2313.0 in raw_data;
# it had most of the features and all of the power that i wanted to replace my desktop machine .
# sentence: 2255.0 out of 2313.0 in raw_data;
# keyboard was also very nice and had a solid feel .
# sentence: 2256.0 out of 2313.0 in raw_data;
# it did not have all the features i expected it to have .
# sentence: 2257.0 out of 2313.0 in raw_data;
# no luck , although i waited for hours on the phone-visited machouse , they stated the their call center is down due to too many phonecalls ( difficult to believe ) .
# sentence: 2258.0 out of 2313.0 in raw_data;
# there is a backlit keyboard which is perfect for typing in the dark .
# sentence: 2259.0 out of 2313.0 in raw_data;
# it has a lot of memory and a great battery life .
# sentence: 2260.0 out of 2313.0 in raw_data;
# it has a lot of memory and a great battery life .
# sentence: 2261.0 out of 2313.0 in raw_data;
# i spoke with a service rep at micro center and his girlfriend is having the same problem with her power adapter , so it 's not just an isolated incident ! ! !
# sentence: 2262.0 out of 2313.0 in raw_data;
# i spoke with a service rep at micro center and his girlfriend is having the same problem with her power adapter , so it 's not just an isolated incident ! ! !
# sentence: 2263.0 out of 2313.0 in raw_data;
# i love this program , it is superior to windows movie maker .
# sentence: 2264.0 out of 2313.0 in raw_data;
# i love this program , it is superior to windows movie maker .
# sentence: 2265.0 out of 2313.0 in raw_data;
# he has replaced his hard drive twice and ( of course ) has had to pay for antivirus software every year .
# sentence: 2266.0 out of 2313.0 in raw_data;
# he has replaced his hard drive twice and ( of course ) has had to pay for antivirus software every year .
# sentence: 2267.0 out of 2313.0 in raw_data;
# this purchase opened me to the world of macbooks , and i am impressed with the intuition of the design , the beauty of the product , and the excellent technological advances associated with it .
# sentence: 2268.0 out of 2313.0 in raw_data;
# this purchase opened me to the world of macbooks , and i am impressed with the intuition of the design , the beauty of the product , and the excellent technological advances associated with it .
# sentence: 2269.0 out of 2313.0 in raw_data;
# the price is great for this model , i only plan on using it for media in the entertainment room .
# sentence: 2270.0 out of 2313.0 in raw_data;
# it seemed to be a very nice laptop except i was not able to load my garmin gps software or microsoft office 2003 .
# sentence: 2271.0 out of 2313.0 in raw_data;
# it seemed to be a very nice laptop except i was not able to load my garmin gps software or microsoft office 2003 .
# sentence: 2272.0 out of 2313.0 in raw_data;
# i 've also had to have the keyboard replaced at my expense .
# sentence: 2273.0 out of 2313.0 in raw_data;
# i had the staff telling me older version did not make the fan noise cause it is a `` different '' computer .
# sentence: 2274.0 out of 2313.0 in raw_data;
# i had the staff telling me older version did not make the fan noise cause it is a `` different '' computer .
# sentence: 2275.0 out of 2313.0 in raw_data;
# was very much worth the price i paid .
# sentence: 2276.0 out of 2313.0 in raw_data;
# even out of warranty !
# sentence: 2277.0 out of 2313.0 in raw_data;
# this is a great little computer for the price .
# sentence: 2278.0 out of 2313.0 in raw_data;
# crisp screen , great battery life , and plenty of storage .
# sentence: 2279.0 out of 2313.0 in raw_data;
# crisp screen , great battery life , and plenty of storage .
# sentence: 2280.0 out of 2313.0 in raw_data;
# crisp screen , great battery life , and plenty of storage .
# sentence: 2281.0 out of 2313.0 in raw_data;
# all apple associates are always wiling to help you out with anything , no matter when you purchased the computer and how many years passed .
# sentence: 2282.0 out of 2313.0 in raw_data;
# also , my sister got the exact same laptop ( since they were so cheap ) and after 8 months , the screen split in half just from everyday use .
# sentence: 2283.0 out of 2313.0 in raw_data;
# the toshiba satellite has been more than i expected for the price .
# sentence: 2284.0 out of 2313.0 in raw_data;
# i had to adjust my mousepad sensitivity , because it is very sensitive .
# sentence: 2285.0 out of 2313.0 in raw_data;
# i wish iwork or ms office came with the mac , but ms office does n't even come with most pc laptops .
# sentence: 2286.0 out of 2313.0 in raw_data;
# i wish iwork or ms office came with the mac , but does n't even come with most pc laptops .
# sentence: 2287.0 out of 2313.0 in raw_data;
# i wish iwork or ms office came with the mac , but does n't even come with most pc laptops .
# sentence: 2288.0 out of 2313.0 in raw_data;
# keyboard is plastic and spongey feeling .
# sentence: 2289.0 out of 2313.0 in raw_data;
# previous laptops were pc 's , still have them , but the mac osx is a clean and smooth operating system .
# sentence: 2290.0 out of 2313.0 in raw_data;
# previous laptops were pc 's , still have them , but the mac osx is a clean and smooth operating system .
# sentence: 2291.0 out of 2313.0 in raw_data;
# i also love having the extra calculator number set up on the keyboard which most laptops do not have .
# sentence: 2292.0 out of 2313.0 in raw_data;
# because he said that the hinge is under the motherboard and they have to dismantle the whole thing before it can be tightened .
# sentence: 2293.0 out of 2313.0 in raw_data;
# because he said that the hinge is under the motherboard and they have to dismantle the whole thing before it can be tightened .
# sentence: 2294.0 out of 2313.0 in raw_data;
# you can do it all on this bad boy but the main thing this netbook was desinged for was surfing the web and boy o boy does it ever .
# sentence: 2295.0 out of 2313.0 in raw_data;
# i love my apple , it is quick and easy to use .
# sentence: 2296.0 out of 2313.0 in raw_data;
# with notes saying they replaced the hard drive .
# sentence: 2297.0 out of 2313.0 in raw_data;
# the laptop is relatively simple to use , though i bought macs for dummies , which is well worth $ 2
# sentence: 2298.0 out of 2313.0 in raw_data;
# ca n't close the 2nd hdd bay since there are brackets you have to break off ( even then , it still does n't shut ) that could be a major flaw for the dual hdd user .
# sentence: 2299.0 out of 2313.0 in raw_data;
# no tutorials on the display .
# sentence: 2300.0 out of 2313.0 in raw_data;
# the leather carrying case , keyboard and mouse arrived in two days from memphis warehouse .
# sentence: 2301.0 out of 2313.0 in raw_data;
# the leather carrying case , keyboard and mouse arrived in two days from memphis warehouse .
# sentence: 2302.0 out of 2313.0 in raw_data;
# the leather carrying case , keyboard and mouse arrived in two days from memphis warehouse .
# sentence: 2303.0 out of 2313.0 in raw_data;
# the touch pad is among the best .
# sentence: 2304.0 out of 2313.0 in raw_data;
# thus , when you carry it at a slanted angle , the screen will `` topple '' or `` slide '' down , if you understand what i mean .
# sentence: 2305.0 out of 2313.0 in raw_data;
# it 's now all commodity hardware .
# sentence: 2306.0 out of 2313.0 in raw_data;
# we also use paralles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise .
# sentence: 2307.0 out of 2313.0 in raw_data;
# we also use paralles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise .
# sentence: 2308.0 out of 2313.0 in raw_data;
# we also use paralles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise .
# sentence: 2309.0 out of 2313.0 in raw_data;
# we also use paralles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise .
# sentence: 2310.0 out of 2313.0 in raw_data;
# we also use paralles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise .
# sentence: 2311.0 out of 2313.0 in raw_data;
# how toshiba handles the repair seems to vary , some folks indicate that they were charged for even an intial fix , others had the done 5 times .
# sentence: 2312.0 out of 2313.0 in raw_data;
# i would like to use a different operating system altogether .
# sentence: 2313.0 out of 2313.0 in raw_data;
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-afb7c3e6e2ab> in <module>
#       8       for i in range(j, j + 150, 3):  # Was 0*3, 2530*3, 3
#       9           print("sentence: " + str(i / 3) + " out of " + str(len(lines) / 3) + " in " + "raw_data;")
# ---> 10           target = lines[i + 1].lower().split()
#      11           words = lines[i].lower().split()
#      12           words_l, words_r = [], []
#
# IndexError: list index out of range
