# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanvanberkum/CD-ABSC/blob/main/getBERT_restaurant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
For use on local runtime.

How to run:
- Download the appropriate BERT model from: 
  https://github.com/google-research/bert (here BERT-Base).

- Create a virtual environment (e.g. using anaconda).

- Install tensorflow in your virtual environment (pip install tensorflow==1.15).

- Start a local runtime in your virtual environment using
  https://research.google.com/colaboratory/local-runtimes.html

- Make sure the BERT model is in your system path (here named
  'uncased_L-12_H-768_A-12').

- Make sure all data is available and update the paths at the end of this code.

Adapted from Trusca, Wassenberg, Frasincar and Dekker (2020) for use on a local
runtime

Truşcǎ M.M., Wassenberg D., Frasincar F., Dekker R. (2020) A Hybrid Approach for 
Aspect-Based Sentiment Analysis Using Deep Contextual Word Embeddings and 
Hierarchical Attention. In: Bielikova M., Mikkonen T., Pautasso C. (eds) Web 
Engineering. ICWE 2020. Lecture Notes in Computer Science, vol 12128. Springer, 
Cham. https://doi.org/10.1007/978-3-030-50578-3_25

https://github.com/mtrusca/HAABSA_PLUS_PLUS
'''
# Out:
# "\nFor use on local runtime.\n\nHow to run:\n- Download the appropriate BERT model from: \n  https://github.com/google-research/bert (here BERT-Base).\n\n- Create a virtual environment (e.g. using anaconda).\n\n- Install tensorflow in your virtual environment (pip install tensorflow==1.15).\n\n- Start a local runtime in your virtual environment using\n  https://research.google.com/colaboratory/local-runtimes.html\n\n- Make sure the BERT model is in your system path (here named\n  'uncased_L-12_H-768_A-12').\n\n- Make sure all data is available and update the paths at the end of this code.\n\nAdapted from Trusca, Wassenberg, Frasincar and Dekker (2020) for use on a local\nruntime\n\nTruşcǎ M.M., Wassenberg D., Frasincar F., Dekker R. (2020) A Hybrid Approach for \nAspect-Based Sentiment Analysis Using Deep Contextual Word Embeddings and \nHierarchical Attention. In: Bielikova M., Mikkonen T., Pautasso C. (eds) Web \nEngineering. ICWE 2020. Lecture Notes in Computer Science, vol 12128. Springer, \nCham. https://doi.org/10.1007/978-3-030-50578-3_25\n\nhttps://github.com/mtrusca/HAABSA_PLUS_PLUS\n"

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import sys

sys.path.append('bert-master/')

import codecs
import collections
import json
import re
import os
import pprint
import numpy as np
import tensorflow as tf

import modeling
import tokenization

# %%
BERT_MODEL = 'uncased_L-12_H-768_A-12'
BERT_PRETRAINED_DIR = 'uncased_L-12_H-768_A-12'
LAYERS = [-1, -2, -3, -4]
NUM_TPU_CORES = 8
MAX_SEQ_LENGTH = 87
BERT_CONFIG = BERT_PRETRAINED_DIR + '/bert_config.json'
CHKPT_DIR = BERT_PRETRAINED_DIR + '/bert_model.ckpt'
VOCAB_FILE = BERT_PRETRAINED_DIR + '/vocab.txt'
INIT_CHECKPOINT = BERT_PRETRAINED_DIR + '/bert_model.ckpt'
BATCH_SIZE = 128

# %%
class InputExample(object):

    def __init__(self, unique_id, text_a, text_b=None):
        self.unique_id = unique_id
        self.text_a = text_a
        self.text_b = text_b

# %%
class InputFeatures(object):
    """A single set of features of data."""

    def __init__(self, unique_id, tokens, input_ids, input_mask, input_type_ids):
        self.unique_id = unique_id
        self.tokens = tokens
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.input_type_ids = input_type_ids

# %%
def input_fn_builder(features, seq_length):
    """Creates an `input_fn` closure to be passed to TPUEstimator."""

    all_unique_ids = []
    all_input_ids = []
    all_input_mask = []
    all_input_type_ids = []

    for feature in features:
        all_unique_ids.append(feature.unique_id)
        all_input_ids.append(feature.input_ids)
        all_input_mask.append(feature.input_mask)
        all_input_type_ids.append(feature.input_type_ids)

    def input_fn(params):
        """The actual input function."""
        batch_size = params["batch_size"]

        num_examples = len(features)

        # This is for demo purposes and does NOT scale to large data sets. We do
        # not use Dataset.from_generator() because that uses tf.py_func which is
        # not TPU compatible. The right way to load data is with TFRecordReader.
        d = tf.data.Dataset.from_tensor_slices({
            "unique_ids":
                tf.constant(all_unique_ids, shape=[num_examples], dtype=tf.int32),
            "input_ids":
                tf.constant(
                    all_input_ids, shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "input_mask":
                tf.constant(
                    all_input_mask,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "input_type_ids":
                tf.constant(
                    all_input_type_ids,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
        })

        d = d.batch(batch_size=batch_size, drop_remainder=False)
        return d

    return input_fn

# %%
def model_fn_builder(bert_config, init_checkpoint, layer_indexes, use_tpu,
                     use_one_hot_embeddings):
    """Returns `model_fn` closure for TPUEstimator."""

    def model_fn(features, labels, mode, params):  # pylint: disable=unused-argument
        """The `model_fn` for TPUEstimator."""

        unique_ids = features["unique_ids"]
        input_ids = features["input_ids"]
        input_mask = features["input_mask"]
        input_type_ids = features["input_type_ids"]

        model = modeling.BertModel(
            config=bert_config,
            is_training=False,
            input_ids=input_ids,
            input_mask=input_mask,
            token_type_ids=input_type_ids,
            use_one_hot_embeddings=use_one_hot_embeddings)

        if mode != tf.estimator.ModeKeys.PREDICT:
            raise ValueError("Only PREDICT modes are supported: %s" % (mode))

        tvars = tf.trainable_variables()
        scaffold_fn = None
        (assignment_map,
         initialized_variable_names) = modeling.get_assignment_map_from_checkpoint(
            tvars, init_checkpoint)
        if use_tpu:

            def tpu_scaffold():
                tf.train.init_from_checkpoint(init_checkpoint, assignment_map)
                return tf.train.Scaffold()

            scaffold_fn = tpu_scaffold
        else:
            tf.train.init_from_checkpoint(init_checkpoint, assignment_map)

        tf.logging.info("**** Trainable Variables ****")
        for var in tvars:
            init_string = ""
            if var.name in initialized_variable_names:
                init_string = ", *INIT_FROM_CKPT*"
            tf.logging.info("  name = %s, shape = %s%s", var.name, var.shape,
                            init_string)

        all_layers = model.get_all_encoder_layers()

        predictions = {
            "unique_id": unique_ids,
        }

        for (i, layer_index) in enumerate(layer_indexes):
            predictions["layer_output_%d" % i] = all_layers[layer_index]

        output_spec = tf.contrib.tpu.TPUEstimatorSpec(
            mode=mode, predictions=predictions, scaffold_fn=scaffold_fn)
        return output_spec

    return model_fn

# %%
def convert_examples_to_features(examples, seq_length, tokenizer):
    """Loads a data file into a list of `InputBatch`s."""

    features = []
    for (ex_index, example) in enumerate(examples):
        tokens_a = tokenizer.tokenize(example.text_a)

        tokens_b = None
        if example.text_b:
            tokens_b = tokenizer.tokenize(example.text_b)

        if tokens_b:
            # Modifies `tokens_a` and `tokens_b` in place so that the total
            # length is less than the specified length.
            # Account for [CLS], [SEP], [SEP] with "- 3"
            _truncate_seq_pair(tokens_a, tokens_b, seq_length - 3)
        else:
            # Account for [CLS] and [SEP] with "- 2"
            if len(tokens_a) > seq_length - 2:
                tokens_a = tokens_a[0:(seq_length - 2)]

        tokens = []
        input_type_ids = []
        tokens.append("[CLS]")
        input_type_ids.append(0)
        for token in tokens_a:
            tokens.append(token)
            input_type_ids.append(0)
        tokens.append("[SEP]")
        input_type_ids.append(0)

        if tokens_b:
            for token in tokens_b:
                tokens.append(token)
                input_type_ids.append(1)
            tokens.append("[SEP]")
            input_type_ids.append(1)

        input_ids = tokenizer.convert_tokens_to_ids(tokens)

        # The mask has 1 for real tokens and 0 for padding tokens. Only real
        # tokens are attended to.
        input_mask = [1] * len(input_ids)

        # Zero-pad up to the sequence length.
        while len(input_ids) < seq_length:
            input_ids.append(0)
            input_mask.append(0)
            input_type_ids.append(0)

        assert len(input_ids) == seq_length
        assert len(input_mask) == seq_length
        assert len(input_type_ids) == seq_length

        if ex_index < 5:
            tf.logging.info("*** Example ***")
            tf.logging.info("unique_id: %s" % (example.unique_id))
            tf.logging.info("tokens: %s" % " ".join(
                [tokenization.printable_text(x) for x in tokens]))
            tf.logging.info("input_ids: %s" % " ".join([str(x) for x in input_ids]))
            tf.logging.info("input_mask: %s" % " ".join([str(x) for x in input_mask]))
            tf.logging.info(
                "input_type_ids: %s" % " ".join([str(x) for x in input_type_ids]))

        features.append(
            InputFeatures(
                unique_id=example.unique_id,
                tokens=tokens,
                input_ids=input_ids,
                input_mask=input_mask,
                input_type_ids=input_type_ids))
    return features

# %%
def _truncate_seq_pair(tokens_a, tokens_b, max_length):
    """Truncates a sequence pair in place to the maximum length."""

    # This is a simple heuristic which will always truncate the longer sequence
    # one token at a time. This makes more sense than truncating an equal percent
    # of tokens from each, since if one sequence is very short then each token
    # that's truncated likely contains more information than a longer sequence.
    while True:
        total_length = len(tokens_a) + len(tokens_b)
        if total_length <= max_length:
            break
        if len(tokens_a) > len(tokens_b):
            tokens_a.pop()
        else:
            tokens_b.pop()

# %%
def read_sequence(input_sentences):
    examples = []
    unique_id = 0
    for sentence in input_sentences:
        line = tokenization.convert_to_unicode(sentence)
        examples.append(InputExample(unique_id=unique_id, text_a=line))
        unique_id += 1
    return examples

# %%
def get_features(input_text, dim=768):
    tf.logging.set_verbosity(tf.logging.ERROR)

    layer_indexes = LAYERS

    bert_config = modeling.BertConfig.from_json_file(BERT_CONFIG)

    tokenizer = tokenization.FullTokenizer(
        vocab_file=VOCAB_FILE, do_lower_case=True)

    examples = read_sequence(input_text)

    features = convert_examples_to_features(
        examples=examples, seq_length=MAX_SEQ_LENGTH, tokenizer=tokenizer)

    unique_id_to_feature = {}
    for feature in features:
        unique_id_to_feature[feature.unique_id] = feature

    model_fn = model_fn_builder(
        bert_config=bert_config,
        init_checkpoint=INIT_CHECKPOINT,
        layer_indexes=layer_indexes,
        use_tpu=False,
        use_one_hot_embeddings=True)

    # If TPU is not available, this will fall back to normal Estimator on CPU
    # or GPU.
    estimator = tf.contrib.tpu.TPUEstimator(
        use_tpu=False,
        model_dir=BERT_PRETRAINED_DIR,
        model_fn=model_fn,
        config=tf.contrib.tpu.RunConfig(),
        predict_batch_size=BATCH_SIZE,
        train_batch_size=BATCH_SIZE)

    input_fn = input_fn_builder(
        features=features, seq_length=MAX_SEQ_LENGTH)

    # Get features
    for result in estimator.predict(input_fn, yield_single_examples=True):
        unique_id = int(result["unique_id"])
        feature = unique_id_to_feature[unique_id]
        output = collections.OrderedDict()
        for (i, token) in enumerate(feature.tokens):
            layers = []
            for (j, layer_index) in enumerate(layer_indexes):
                layer_output = result["layer_output_%d" % j]
                layer_output_flat = np.array([x for x in layer_output[i:(i + 1)].flat])
                layers.append(layer_output_flat)
            output[token] = sum(layers)[:dim]

    return output

# %%
# When it takes too long, data can be split in multiple subfiles such as in
# lines 5-30
lines = open('data/programGeneratedData/BERT/restaurant/raw_data_restaurant_2015.txt', errors='replace').readlines()


for j in range(0, len(lines), 150):
  with open("BERT_base_restaurant_2015_" + str(round(j/150)) + ".txt", 'w') as f:
      for i in range(j, j + 150, 3):  # Was 0*3, 2530*3, 3
          print("sentence: " + str(i / 3) + " out of " + str(len(lines) / 3) + " in " + "raw_data;")
          target = lines[i + 1].lower().split()
          words = lines[i].lower().split()
          words_l, words_r = [], []
          flag = True
          for word in words:
              if word == '$t$':
                  flag = False
                  continue
              if flag:
                  words_l.append(word)
              else:
                  words_r.append(word)
          sentence = " ".join(words_l + target + words_r)
          print(sentence)
          embeddings = get_features([sentence])

          for key, value in embeddings.items():
              f.write('\n%s ' % key)
              for v in value:
                f.write('%s ' % v)
'''

with open("dataBERT/BERT_base_restaurant_2014.txt", 'w') as f:
  for i in range(0, len(lines), 3):  # Was 0*3, 2530*3, 3
    print("sentence: " + str(i / 3) + " out of " + str(len(lines) / 3) + " in " + "raw_data;")
    target = lines[i + 1].lower().split()
    words = lines[i].lower().split()
    words_l, words_r = [], []
    flag = True
    for word in words:
      if word == '$t$':
        flag = False
        continue
      if flag:
        words_l.append(word)
      else:
        words_r.append(word)
    sentence = " ".join(words_l + target + words_r)
    print(sentence)
    embeddings = get_features([sentence])

    for key, value in embeddings.items():
      f.write('\n%s ' % key)
      for v in value:
        f.write('%s ' % v)

'''
# Out:
# sentence: 0.0 out of 1880.0 in raw_data;
# judging from previous posts this used to be a good place , but not any longer .
# sentence: 1.0 out of 1880.0 in raw_data;
# we , there were four of us , arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude .
# sentence: 2.0 out of 1880.0 in raw_data;
# the food was lousy - too sweet or too salty and the portions tiny .
# sentence: 3.0 out of 1880.0 in raw_data;
# the food was lousy - too sweet or too salty and the portions tiny .
# sentence: 4.0 out of 1880.0 in raw_data;
# avoid this place !
# sentence: 5.0 out of 1880.0 in raw_data;
# i have eaten at saul , many times , the food is always consistently , outrageously good .
# sentence: 6.0 out of 1880.0 in raw_data;
# saul is the best restaurant on smith street and in brooklyn .
# sentence: 7.0 out of 1880.0 in raw_data;
# the duck confit is always amazing and the foie gras terrine with figs was out of this world .
# sentence: 8.0 out of 1880.0 in raw_data;
# the duck confit is always amazing and the foie gras terrine with figs was out of this world .
# sentence: 9.0 out of 1880.0 in raw_data;
# the wine list is interesting and has many good values .
# sentence: 10.0 out of 1880.0 in raw_data;
# the wine list is interesting and has many good values .
# sentence: 11.0 out of 1880.0 in raw_data;
# i was very disappointed with this restaurant .
# sentence: 12.0 out of 1880.0 in raw_data;
# ive asked a cart attendant for a lotus leaf wrapped rice and she replied back rice and just walked away .
# sentence: 13.0 out of 1880.0 in raw_data;
# food was okay , nothing great .
# sentence: 14.0 out of 1880.0 in raw_data;
# chow fun was dry ; pork shu mai was more than usually greasy and had to share a table with loud and rude family .
# sentence: 15.0 out of 1880.0 in raw_data;
# chow fun was dry ; pork shu mai was more than usually greasy and had to share a table with loud and rude family .
# sentence: 16.0 out of 1880.0 in raw_data;
# i/we will never go back to this place again .
# sentence: 17.0 out of 1880.0 in raw_data;
# went on a 3 day oyster binge , with fish bringing up the closing , and i am so glad this was the place it o trip ended , because it was so great !
# sentence: 18.0 out of 1880.0 in raw_data;
# service was devine , oysters where a sensual as they come , and the price ca n't be beat ! ! !
# sentence: 19.0 out of 1880.0 in raw_data;
# service was devine , oysters where a sensual as they come , and the price ca n't be beat ! ! !
# sentence: 20.0 out of 1880.0 in raw_data;
# every time in new york i make it a point to visit restaurant saul on smith street .
# sentence: 21.0 out of 1880.0 in raw_data;
# everything is always cooked to perfection , the service is excellent , the decor cool and understated .
# sentence: 22.0 out of 1880.0 in raw_data;
# everything is always cooked to perfection , the service is excellent , the decor cool and understated .
# sentence: 23.0 out of 1880.0 in raw_data;
# i had the duck breast special on my last visit and it was incredible .
# sentence: 24.0 out of 1880.0 in raw_data;
# the food is very average ... the thai fusion stuff is a bit too sweet , every thing they serve is too sweet here .
# sentence: 25.0 out of 1880.0 in raw_data;
# the food is very average ... the thai fusion stuff is a bit too sweet , every thing they serve is too sweet here .
# sentence: 26.0 out of 1880.0 in raw_data;
# the only thing i moderately enjoyed was their grilled chicken special with edamame puree .
# sentence: 27.0 out of 1880.0 in raw_data;
# i had never had edamame pureed before but i thought it was innovative and tasty ( could 've used a bit more salt ) .
# sentence: 28.0 out of 1880.0 in raw_data;
# i had never had edamame pureed before but i thought it was innovative and tasty ( could 've used a bit more salt ) .
# sentence: 29.0 out of 1880.0 in raw_data;
# the decor is night tho ... but they really need to clean that vent in the ceiling ... its quite un-appetizing , and kills your effort to make this place look sleek and modern .
# sentence: 30.0 out of 1880.0 in raw_data;
# the decor is night tho ... but they really need to clean that vent in the ceiling ... its quite un-appetizing , and kills your effort to make this place look sleek and modern .
# sentence: 31.0 out of 1880.0 in raw_data;
# the decor is night tho ... but they really need to clean that vent in the ceiling ... its quite un-appetizing , and kills your effort to make this place look sleek and modern .
# sentence: 32.0 out of 1880.0 in raw_data;
# their sake list was extensive , but we were looking for purple haze , which was n't listed but made for us upon request !
# sentence: 33.0 out of 1880.0 in raw_data;
# the spicy tuna roll was unusually good and the rock shrimp tempura was awesome , great appetizer to share !
# sentence: 34.0 out of 1880.0 in raw_data;
# the spicy tuna roll was unusually good and the rock shrimp tempura was awesome , great appetizer to share !
# sentence: 35.0 out of 1880.0 in raw_data;
# we went around 9:30 on a friday and it had died down a bit by then so the service was great !
# sentence: 36.0 out of 1880.0 in raw_data;
# we love th pink pony .
# sentence: 37.0 out of 1880.0 in raw_data;
# the perfect spot .
# sentence: 38.0 out of 1880.0 in raw_data;
# $t$-awesome . food
# sentence: 39.0 out of 1880.0 in raw_data;
# $t$- friendly and attentive . service
# sentence: 40.0 out of 1880.0 in raw_data;
# $t$- relaxed and stylish . ambiance
# sentence: 41.0 out of 1880.0 in raw_data;
# do n't judge this place prima facie , you have to try it to believe it , a home away from home for the literate heart .
# sentence: 42.0 out of 1880.0 in raw_data;
# the food is decent .
# sentence: 43.0 out of 1880.0 in raw_data;
# however , it 's the service that leaves a bad taste in my mouth .
# sentence: 44.0 out of 1880.0 in raw_data;
# i happen to have a policy that goes along with a little bit of self-respect , which includes not letting a waiter intimidate me , i.e . make me feel bad asking for trivialities like water , or the check .
# sentence: 45.0 out of 1880.0 in raw_data;
# this place has got to be the best japanese restaurant in the new york area .
# sentence: 46.0 out of 1880.0 in raw_data;
# food is great .
# sentence: 47.0 out of 1880.0 in raw_data;
# service is top notch .
# sentence: 48.0 out of 1880.0 in raw_data;
# i tend to judge a sushi restaurant by its sea urchin , which was heavenly at sushi rose .
# sentence: 49.0 out of 1880.0 in raw_data;
# the sushi seemed pretty fresh and was adequately proportioned .
# sentence: 50.0 out of 1880.0 in raw_data;
# the sushi seemed pretty fresh and was adequately proportioned .
# sentence: 51.0 out of 1880.0 in raw_data;
# the rice to fish ration was also good -- they did n't try to overpack the rice .
# sentence: 52.0 out of 1880.0 in raw_data;
# we took advanatage of the half price sushi deal on saturday so it was well worth it .
# sentence: 53.0 out of 1880.0 in raw_data;
# we took advanatage of the half price sushi deal on saturday so it was well worth it .
# sentence: 54.0 out of 1880.0 in raw_data;
# in the evening , this place attracted a well dressed , with it , ny crowd .
# sentence: 55.0 out of 1880.0 in raw_data;
# the food was well prepared and the service impecable .
# sentence: 56.0 out of 1880.0 in raw_data;
# the food was well prepared and the service impecable .
# sentence: 57.0 out of 1880.0 in raw_data;
# the prix fixe menu is worth every penny and you get more than enough ( both in quantity and quality ) .
# sentence: 58.0 out of 1880.0 in raw_data;
# the prix fixe menu is worth every penny and you get more than enough ( both in quantity and quality ) .
# sentence: 59.0 out of 1880.0 in raw_data;
# the prix fixe menu is worth every penny and you get more than enough ( both in quantity and quality ) .
# sentence: 60.0 out of 1880.0 in raw_data;
# $ 6 and there is much tasty food , all of it fresh and continually refilled .
# sentence: 61.0 out of 1880.0 in raw_data;
# $ 6 and there is much tasty food , all of it fresh and continually refilled .
# sentence: 62.0 out of 1880.0 in raw_data;
# $ 6 and there is much tasty food , all of it fresh and continually refilled .
# sentence: 63.0 out of 1880.0 in raw_data;
# i am not a vegetarian but , almost all the dishes were great .
# sentence: 64.0 out of 1880.0 in raw_data;
# the food here is rather good , but only if you like to wait for it .
# sentence: 65.0 out of 1880.0 in raw_data;
# i like the somosas , chai , and the chole , but the dhosas and dhal were kinda dissapointing .
# sentence: 66.0 out of 1880.0 in raw_data;
# i like the somosas , chai , and the chole , but the dhosas and dhal were kinda dissapointing .
# sentence: 67.0 out of 1880.0 in raw_data;
# i like the somosas , chai , and the chole , but the dhosas and dhal were kinda dissapointing .
# sentence: 68.0 out of 1880.0 in raw_data;
# i like the somosas , chai , and the chole , but the dhosas and dhal were kinda dissapointing .
# sentence: 69.0 out of 1880.0 in raw_data;
# i like the somosas , chai , and the chole , but the dhosas and dhal were kinda dissapointing .
# sentence: 70.0 out of 1880.0 in raw_data;
# the service varys from day to day- sometimes they 're very nice , and sometimes not .
# sentence: 71.0 out of 1880.0 in raw_data;
# the kitchen however , is almost always slow .
# sentence: 72.0 out of 1880.0 in raw_data;
# also , specify if you like your food spicy- its rather bland if you do n't .
# sentence: 73.0 out of 1880.0 in raw_data;
# the ambience is pretty and nice for conversation , so a casual lunch here would probably be best .
# sentence: 74.0 out of 1880.0 in raw_data;
# if you 've ever been along the river in weehawken you have an idea of the top of view the chart house has to offer .
# sentence: 75.0 out of 1880.0 in raw_data;
# add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening .
# sentence: 76.0 out of 1880.0 in raw_data;
# add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening .
# sentence: 77.0 out of 1880.0 in raw_data;
# add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening .
# sentence: 78.0 out of 1880.0 in raw_data;
# the lava cake dessert was incredible and i recommend it .
# sentence: 79.0 out of 1880.0 in raw_data;
# once you step into cosette , you 're miraculously in a small , off-the-beaten path parisian bistro .
# sentence: 80.0 out of 1880.0 in raw_data;
# this tiny restaurant is as cozy as it gets , with that certain parisian flair .
# sentence: 81.0 out of 1880.0 in raw_data;
# the food was average to above-average ; the french onion soup filling yet not overly impressive , and the desserts not brilliant in any way .
# sentence: 82.0 out of 1880.0 in raw_data;
# the food was average to above-average ; the french onion soup filling yet not overly impressive , and the desserts not brilliant in any way .
# sentence: 83.0 out of 1880.0 in raw_data;
# the food was average to above-average ; the french onion soup filling yet not overly impressive , and the desserts not brilliant in any way .
# sentence: 84.0 out of 1880.0 in raw_data;
# the food was average to above-average ; the french onion soup filling yet not overly impressive , and the desserts not brilliant in any way .
# sentence: 85.0 out of 1880.0 in raw_data;
# however , go for the ambience , and consider the food just a companion for a trip across the world !
# sentence: 86.0 out of 1880.0 in raw_data;
# however , go for the ambience , and consider the food just a companion for a trip across the world !
# sentence: 87.0 out of 1880.0 in raw_data;
# the pizza was delivered cold and the cheese was n't even fully melted !
# sentence: 88.0 out of 1880.0 in raw_data;
# the pizza was delivered cold and the cheese was n't even fully melted !
# sentence: 89.0 out of 1880.0 in raw_data;
# the pizza is overpriced and soggy .
# sentence: 90.0 out of 1880.0 in raw_data;
# the pizza is overpriced and soggy .
# sentence: 91.0 out of 1880.0 in raw_data;
# yes , they use fancy ingredients , but even fancy do n't make for good pizza unless someone knows how to get the crust right .
# sentence: 92.0 out of 1880.0 in raw_data;
# yes , they use fancy ingredients , but even fancy ingredients do n't make for good pizza unless someone knows how to get the crust right .
# sentence: 93.0 out of 1880.0 in raw_data;
# yes , they use fancy ingredients , but even fancy ingredients do n't make for good pizza unless someone knows how to get the crust right .
# sentence: 94.0 out of 1880.0 in raw_data;
# i think i 've had some the best meals of my life at minnow .
# sentence: 95.0 out of 1880.0 in raw_data;
# the seafood is amazing , there 's a good wine list , and the ever-changing menu always offers some great surprises .
# sentence: 96.0 out of 1880.0 in raw_data;
# the seafood is amazing , there 's a good wine list , and the ever-changing menu always offers some great surprises .
# sentence: 97.0 out of 1880.0 in raw_data;
# the seafood is amazing , there 's a good wine list , and the ever-changing menu always offers some great surprises .
# sentence: 98.0 out of 1880.0 in raw_data;
# the combination of super-fresh ingredients in the dishes are unusual but really delicious .
# sentence: 99.0 out of 1880.0 in raw_data;
# best pastrami i ever had and great portion without being ridiculous .
# sentence: 100.0 out of 1880.0 in raw_data;
# best pastrami i ever had and great portion without being ridiculous .
# sentence: 101.0 out of 1880.0 in raw_data;
# my wife had the fried shrimp which are huge and loved it .
# sentence: 102.0 out of 1880.0 in raw_data;
# my wife had the fried shrimp which are huge and loved it .
# sentence: 103.0 out of 1880.0 in raw_data;
# as a japanese native , i 've lived in the tristate area for over 8 years , but i was just so amazed at this place .
# sentence: 104.0 out of 1880.0 in raw_data;
# this place is the most japanese it can ever get .
# sentence: 105.0 out of 1880.0 in raw_data;
# the signs , the specials menus , food , and even all the waitstaff are all totally japanese .
# sentence: 106.0 out of 1880.0 in raw_data;
# the signs , the specials menus , food , and even all the waitstaff are all totally japanese .
# sentence: 107.0 out of 1880.0 in raw_data;
# the signs , the specials menus , food , and even all the waitstaff are all totally japanese .
# sentence: 108.0 out of 1880.0 in raw_data;
# the signs , the specials menus , food , and even all the waitstaff are all totally japanese .
# sentence: 109.0 out of 1880.0 in raw_data;
# this place is worth an one-hour drive .
# sentence: 110.0 out of 1880.0 in raw_data;
# leon is an east village gem : casual but hip , with well prepared basic french bistro fare , good specials , a warm and lively atmosphere .
# sentence: 111.0 out of 1880.0 in raw_data;
# leon is an east village gem : casual but hip , with well prepared basic french bistro fare , good specials , a warm and lively atmosphere .
# sentence: 112.0 out of 1880.0 in raw_data;
# leon is an east village gem : casual but hip , with well prepared basic french bistro fare , good specials , a warm and lively atmosphere .
# sentence: 113.0 out of 1880.0 in raw_data;
# leon is an east village gem : casual but hip , with well prepared basic french bistro fare , good specials , a warm and lively atmosphere .
# sentence: 114.0 out of 1880.0 in raw_data;
# leon is an east village gem : casual but hip , with well prepared basic french bistro fare , good specials , a warm and lively atmosphere .
# sentence: 115.0 out of 1880.0 in raw_data;
# my wife and i always enjoy the young , not always well trained but nevertheless friendly , staff , all of whom have a story .
# sentence: 116.0 out of 1880.0 in raw_data;
# decent wine at reasonable prices .
# sentence: 117.0 out of 1880.0 in raw_data;
# decent wine at reasonable prices .
# sentence: 118.0 out of 1880.0 in raw_data;
# everytime i decide to try another place on the ues , i get angry that i did n't just go to zucchero pomodori .
# sentence: 119.0 out of 1880.0 in raw_data;
# this is by far my favorite place in the neighborhood .
# sentence: 120.0 out of 1880.0 in raw_data;
# the service is excellent , the decor is great , and the food is delicious and comes in large portions .
# sentence: 121.0 out of 1880.0 in raw_data;
# the service is excellent , the decor is great , and the food is delicious and comes in large portions .
# sentence: 122.0 out of 1880.0 in raw_data;
# the service is excellent , the decor is great , and the food is delicious and comes in large portions .
# sentence: 123.0 out of 1880.0 in raw_data;
# the service is excellent , the decor is great , and the food is delicious and comes in large portions .
# sentence: 124.0 out of 1880.0 in raw_data;
# i 'm partial to the gnocchi .
# sentence: 125.0 out of 1880.0 in raw_data;
# this place is incredibly tiny .
# sentence: 126.0 out of 1880.0 in raw_data;
# the hostess is rude to the point of being offensive .
# sentence: 127.0 out of 1880.0 in raw_data;
# the food was bland oily .
# sentence: 128.0 out of 1880.0 in raw_data;
# we have been to this place many times , and always have great food , wine , and service .
# sentence: 129.0 out of 1880.0 in raw_data;
# we have been to this place many times , and always have great food , wine , and service .
# sentence: 130.0 out of 1880.0 in raw_data;
# we have been to this place many times , and always have great food , wine , and service .
# sentence: 131.0 out of 1880.0 in raw_data;
# we were worried we would have trouble getting in , but somehow managed to have a short wait .
# sentence: 132.0 out of 1880.0 in raw_data;
# as always we had a great glass of wine while we waited .
# sentence: 133.0 out of 1880.0 in raw_data;
# when we sat , we got great and fast service .
# sentence: 134.0 out of 1880.0 in raw_data;
# the people that work there are always so friendly you forget you are in new york sometimes .
# sentence: 135.0 out of 1880.0 in raw_data;
# make sure you try this place as often as you can .
# sentence: 136.0 out of 1880.0 in raw_data;
# this is a fun restaurant to go to .
# sentence: 137.0 out of 1880.0 in raw_data;
# the pizza is yummy and i like the atmoshpere .
# sentence: 138.0 out of 1880.0 in raw_data;
# the pizza is yummy and i like the atmoshpere .
# sentence: 139.0 out of 1880.0 in raw_data;
# but the pizza is way to expensive .
# sentence: 140.0 out of 1880.0 in raw_data;
# a large is $ 20 , and toppings are about $ 3 each .
# sentence: 141.0 out of 1880.0 in raw_data;
# i went there for lunch and it was not as good as i expected from the reviews i read .
# sentence: 142.0 out of 1880.0 in raw_data;
# sauce was watery and the food did n't have much flavor .
# sentence: 143.0 out of 1880.0 in raw_data;
# sauce was watery and the food did n't have much flavor .
# sentence: 144.0 out of 1880.0 in raw_data;
# this place is great .
# sentence: 145.0 out of 1880.0 in raw_data;
# the waitress was very patient with us and the food is phenomenal !
# sentence: 146.0 out of 1880.0 in raw_data;
# the waitress was very patient with us and the food is phenomenal !
# sentence: 147.0 out of 1880.0 in raw_data;
# service was prompt , friendly and great .
# sentence: 148.0 out of 1880.0 in raw_data;
# great pizza and fantastic service .
# sentence: 149.0 out of 1880.0 in raw_data;
# great pizza and fantastic service .
# sentence: 150.0 out of 1880.0 in raw_data;
# there was a small wait , but shorter than i expected .
# sentence: 151.0 out of 1880.0 in raw_data;
# located at the end of a magnificent block .
# sentence: 152.0 out of 1880.0 in raw_data;
# this is the best sushi in new york city - hands down .
# sentence: 153.0 out of 1880.0 in raw_data;
# the place is small and cramped but the food is fantastic .
# sentence: 154.0 out of 1880.0 in raw_data;
# the place is small and cramped but the food is fantastic .
# sentence: 155.0 out of 1880.0 in raw_data;
# get the tuna of gari .
# sentence: 156.0 out of 1880.0 in raw_data;
# planet thailand has always been a hit with me , i go there usually for the sushi , which is great , the thai food is excellent too .
# sentence: 157.0 out of 1880.0 in raw_data;
# planet thailand has always been a hit with me , i go there usually for the sushi , which is great , the thai food is excellent too .
# sentence: 158.0 out of 1880.0 in raw_data;
# planet thailand has always been a hit with me , i go there usually for the sushi , which is great , the thai food is excellent too .
# sentence: 159.0 out of 1880.0 in raw_data;
# with the great variety on the menu , i eat here often and never get bored .
# sentence: 160.0 out of 1880.0 in raw_data;
# the atmosphere is n't the greatest , but i suppose that 's how they keep the prices down .
# sentence: 161.0 out of 1880.0 in raw_data;
# it 's all about the food ! !
# sentence: 162.0 out of 1880.0 in raw_data;
# first it took us a long time to find the place .
# sentence: 163.0 out of 1880.0 in raw_data;
# but when we looked at the menu , there were n't a lot of choices , most of them were dumplings in the appetizer section .
# sentence: 164.0 out of 1880.0 in raw_data;
# those rolls were big , but not good and sashimi was n't fresh .
# sentence: 165.0 out of 1880.0 in raw_data;
# those rolls were big , but not good and sashimi was n't fresh .
# sentence: 166.0 out of 1880.0 in raw_data;
# those rolls were big , but not good and sashimi was n't fresh .
# sentence: 167.0 out of 1880.0 in raw_data;
# try the crunchy tuna , it is to die for .
# sentence: 168.0 out of 1880.0 in raw_data;
# first went here to enjoy their garden terrace .
# sentence: 169.0 out of 1880.0 in raw_data;
# the food was amazing , and the service was prompt and helpful , but not over-bearing or rushed .
# sentence: 170.0 out of 1880.0 in raw_data;
# the food was amazing , and the service was prompt and helpful , but not over-bearing or rushed .
# sentence: 171.0 out of 1880.0 in raw_data;
# the steak tartare is a great bet , they fix it for you at the table .
# sentence: 172.0 out of 1880.0 in raw_data;
# admittedly some nights inside the restaurant were rather warm , but the open kitchen is part of the charm .
# sentence: 173.0 out of 1880.0 in raw_data;
# admittedly some nights inside the restaurant were rather warm , but the open kitchen is part of the charm .
# sentence: 174.0 out of 1880.0 in raw_data;
# great wine selection , gigondas is worth the price , and the house champagne is a great value .
# sentence: 175.0 out of 1880.0 in raw_data;
# great wine selection , gigondas is worth the price , and the house champagne is a great value .
# sentence: 176.0 out of 1880.0 in raw_data;
# great wine selection , gigondas is worth the price , and the house champagne is a great value .
# sentence: 177.0 out of 1880.0 in raw_data;
# it may be a bit packed on weekends , but the vibe is good and it is the best french food you will find in the area .
# sentence: 178.0 out of 1880.0 in raw_data;
# it may be a bit packed on weekends , but the vibe is good and it is the best french food you will find in the area .
# sentence: 179.0 out of 1880.0 in raw_data;
# have recommended the place to friends , always gets good response .
# sentence: 180.0 out of 1880.0 in raw_data;
# pizza - the only pizza in nyc that should not have additional toppings - the crust tastes like the best , freshly baked bread !
# sentence: 181.0 out of 1880.0 in raw_data;
# pizza - the only in nyc that should not have additional toppings - the crust tastes like the best , freshly baked bread !
# sentence: 182.0 out of 1880.0 in raw_data;
# i take all my nyc guests to vt 's .
# sentence: 183.0 out of 1880.0 in raw_data;
# not sure where the previous reviewer , lonk , dined , but saul is in a great neighborhood and has great food !
# sentence: 184.0 out of 1880.0 in raw_data;
# not sure where the previous reviewer , lonk , dined , but saul is in a great neighborhood and has great food !
# sentence: 185.0 out of 1880.0 in raw_data;
# i 'd highly recommend it for a special occasion -- it provides and intimate setting and nice service .
# sentence: 186.0 out of 1880.0 in raw_data;
# i 'd highly recommend it for a special occasion -- it provides and intimate setting and nice service .
# sentence: 187.0 out of 1880.0 in raw_data;
# i 'm not sure where the other reviewers ate but it seems as if we visited two different restaurants because my friends and i all enjoy mizu very much ... and we 're repeat customers .
# sentence: 188.0 out of 1880.0 in raw_data;
# make sure you have the $t$.. . spicy scallop roll
# sentence: 189.0 out of 1880.0 in raw_data;
# moules were excellent , lobster ravioli was very salty !
# sentence: 190.0 out of 1880.0 in raw_data;
# moules were excellent , lobster ravioli was very salty !
# sentence: 191.0 out of 1880.0 in raw_data;
# took my mom for mother 's day , and the maitre d ' was pretty rude .
# sentence: 192.0 out of 1880.0 in raw_data;
# tiny dessert was $ 8.00 ... just plain overpriced for what it is .
# sentence: 193.0 out of 1880.0 in raw_data;
# tiny dessert was $ 8.00 ... just plain overpriced for what it is .
# sentence: 194.0 out of 1880.0 in raw_data;
# the drinks are always welll made and wine selection is fairly priced .
# sentence: 195.0 out of 1880.0 in raw_data;
# the drinks are always welll made and wine selection is fairly priced .
# sentence: 196.0 out of 1880.0 in raw_data;
# try their chef 's specials -- they are to die for .
# sentence: 197.0 out of 1880.0 in raw_data;
# service is not exactly five star , but thats not really a big deal .
# sentence: 198.0 out of 1880.0 in raw_data;
# downstairs lounge is always a good attraction
# sentence: 199.0 out of 1880.0 in raw_data;
# raga 's is a romantic , cozy restaurant .
# sentence: 200.0 out of 1880.0 in raw_data;
# the exotic food is beautifully presented and is a delight in delicious combinations .
# sentence: 201.0 out of 1880.0 in raw_data;
# the exotic food is beautifully presented and is a delight in delicious combinations .
# sentence: 202.0 out of 1880.0 in raw_data;
# the staff is incredibly helpful and attentive .
# sentence: 203.0 out of 1880.0 in raw_data;
# the bar is very well stocked with interesting beers and well priced wines .
# sentence: 204.0 out of 1880.0 in raw_data;
# the bar is very well stocked with interesting beers and well priced wines .
# sentence: 205.0 out of 1880.0 in raw_data;
# the bar is very well stocked with interesting beers and well priced wines .
# sentence: 206.0 out of 1880.0 in raw_data;
# when we stumbled on leon , we thought that we had found quite the gem but , we were certainly wrong .
# sentence: 207.0 out of 1880.0 in raw_data;
# the waitress moved our table practically into the bathroom and when we asked to cancel our dinner orders because we did not want to eat sitting on the toilet , we were told no ...
# sentence: 208.0 out of 1880.0 in raw_data;
# rude service , medicore food ... there are tons of restaurants in ny ... stay away from this one
# sentence: 209.0 out of 1880.0 in raw_data;
# rude service , medicore food ... there are tons of restaurants in ny ... stay away from this one
# sentence: 210.0 out of 1880.0 in raw_data;
# i had a grat time at jekyll and hyde !
# sentence: 211.0 out of 1880.0 in raw_data;
# i loved everythig about it-especially the shows and actors .
# sentence: 212.0 out of 1880.0 in raw_data;
# i loved everythig about it-especially the shows and actors .
# sentence: 213.0 out of 1880.0 in raw_data;
# our server was very helpful and friendly .
# sentence: 214.0 out of 1880.0 in raw_data;
# the food was good too .
# sentence: 215.0 out of 1880.0 in raw_data;
# the tuna and wasabe potatoes are excellent .
# sentence: 216.0 out of 1880.0 in raw_data;
# the tuna and wasabe potatoes are excellent .
# sentence: 217.0 out of 1880.0 in raw_data;
# the outdoor atmosphere of sitting on the sidewalk watching the world go by 50 feet away on 6th avenue on a cool evening was wonderful .
# sentence: 218.0 out of 1880.0 in raw_data;
# service was prompt and courteous .
# sentence: 219.0 out of 1880.0 in raw_data;
# great service , great food .
# sentence: 220.0 out of 1880.0 in raw_data;
# great service , great food .
# sentence: 221.0 out of 1880.0 in raw_data;
# the pizza is delicious - they use fresh mozzarella instead of the cheap , frozen , shredded cheese common to most $t$ria 's .
# sentence: 222.0 out of 1880.0 in raw_data;
# the pizza is delicious - they use fresh mozzarella instead of the cheap , frozen , shredded cheese common to most pizzaria 's .
# sentence: 223.0 out of 1880.0 in raw_data;
# two complaints- their appetizer selection stinks , it would be nice to get some mozzarella sticks on the menu .
# sentence: 224.0 out of 1880.0 in raw_data;
# wait staff is blantently unappreciative of your business but its the best pie on the uws !
# sentence: 225.0 out of 1880.0 in raw_data;
# wait staff is blantently unappreciative of your business but its the best pie on the uws !
# sentence: 226.0 out of 1880.0 in raw_data;
# by far the best salad i have had in a fast food restaurant .
# sentence: 227.0 out of 1880.0 in raw_data;
# fine dining restaurant quality .
# sentence: 228.0 out of 1880.0 in raw_data;
# on a recent sunday afternoon , a friend and i accidently found this great restaurant on our way to see the pulitzer prize winning play doubt .
# sentence: 229.0 out of 1880.0 in raw_data;
# the chicken pot pie is excpetiona , the cheeseburger huge and delictable , and the service professional wan warm .
# sentence: 230.0 out of 1880.0 in raw_data;
# the chicken pot pie is excpetiona , the cheeseburger huge and delictable , and the service professional wan warm .
# sentence: 231.0 out of 1880.0 in raw_data;
# the chicken pot pie is excpetiona , the cheeseburger huge and delictable , and the service professional wan warm .
# sentence: 232.0 out of 1880.0 in raw_data;
# the chicken pot pie is excpetiona , the cheeseburger huge and delictable , and the service professional wan warm .
# sentence: 233.0 out of 1880.0 in raw_data;
# the staff is no nonsense .
# sentence: 234.0 out of 1880.0 in raw_data;
# the food options rule .
# sentence: 235.0 out of 1880.0 in raw_data;
# when i lived upstate for a while i would buy freeze the bagels and they would still be better than any else .
# sentence: 236.0 out of 1880.0 in raw_data;
# worth visiting the 1st ave spot because it is the original store .
# sentence: 237.0 out of 1880.0 in raw_data;
# he served me an uni hand roll , which i never had before , and let me tell you ... it was heaven !
# sentence: 238.0 out of 1880.0 in raw_data;
# the sake menu should not be overlooked !
# sentence: 239.0 out of 1880.0 in raw_data;
# try the lobster teriyaki and the rose special roll .
# sentence: 240.0 out of 1880.0 in raw_data;
# try the lobster teriyaki and the rose special roll .
# sentence: 241.0 out of 1880.0 in raw_data;
# service was very good - prompt , attentive and non-intrusive .
# sentence: 242.0 out of 1880.0 in raw_data;
# food was very good as well , considering that we tried the budget selection ( though i wish the pork belly that i ordered was roasted a bit longer , so that fat was more of a melt-in-your-mouth experience ) .
# sentence: 243.0 out of 1880.0 in raw_data;
# food was very good as well , considering that we tried the budget selection ( though i wish the pork belly that i ordered was roasted a bit longer , so that fat was more of a melt-in-your-mouth experience ) .
# sentence: 244.0 out of 1880.0 in raw_data;
# wine list selection is good and wine-by-the-glass was generously filled to the top .
# sentence: 245.0 out of 1880.0 in raw_data;
# wine list selection is good and wine-by-the-glass was generously filled to the top .
# sentence: 246.0 out of 1880.0 in raw_data;
# traditional french decour was pleasant though the hall was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation .
# sentence: 247.0 out of 1880.0 in raw_data;
# traditional french decour was pleasant though the hall was rather noisy - the restaurant was full and we had to raise our voices to be able to maintain a conversation .
# sentence: 248.0 out of 1880.0 in raw_data;
# i 've been to at cafe spice probably 5-8 times , it is probably still the best indian restaurant around union square .
# sentence: 249.0 out of 1880.0 in raw_data;
# to sum it up : service varies from good to mediorce , depending on which waiter you get ; generally it is just average ok .
# sentence: 250.0 out of 1880.0 in raw_data;
# seating is always prompt , though the restaurant does fill up in the evening .
# sentence: 251.0 out of 1880.0 in raw_data;
# food is usually very good , though ocasionally i wondered about freshmess of raw vegatables in side orders .
# sentence: 252.0 out of 1880.0 in raw_data;
# food is usually very good , though ocasionally i wondered about freshmess of raw vegatables in side orders .
# sentence: 253.0 out of 1880.0 in raw_data;
# the decor is vibrant and eye-pleasing with several semi-private boths on the right side of the dining hall , which are great for a date .
# sentence: 254.0 out of 1880.0 in raw_data;
# the decor is vibrant and eye-pleasing with several semi-private boths on the right side of the dining hall , which are great for a date .
# sentence: 255.0 out of 1880.0 in raw_data;
# i have never been disappointed in the red eye .
# sentence: 256.0 out of 1880.0 in raw_data;
# the first time i went , and was completely taken by the live jazz band and atmosphere , i ordered the lobster cobb salad .
# sentence: 257.0 out of 1880.0 in raw_data;
# the first time i went , and was completely taken by the live jazz band and atmosphere , i ordered the lobster cobb salad .
# sentence: 258.0 out of 1880.0 in raw_data;
# it 's simply the best meal in nyc .
# sentence: 259.0 out of 1880.0 in raw_data;
# you can not go wrong at the red eye grill .
# sentence: 260.0 out of 1880.0 in raw_data;
# if we were to move from the upper east side , we would genuinely miss this restaurant .
# sentence: 261.0 out of 1880.0 in raw_data;
# the restaurant is cute but not upscale .
# sentence: 262.0 out of 1880.0 in raw_data;
# the food is a diamond in rough -- the is delicious and homemade with the perfect balance of herbs and tomatoes .
# sentence: 263.0 out of 1880.0 in raw_data;
# the food is a diamond in rough -- the food is delicious and homemade with the perfect balance of herbs and tomatoes .
# sentence: 264.0 out of 1880.0 in raw_data;
# we had a great time at the jekyll and hyde pub last night .
# sentence: 265.0 out of 1880.0 in raw_data;
# after really enjoying ourselves at the bar we sat down at a table and had dinner .
# sentence: 266.0 out of 1880.0 in raw_data;
# the server was really cool and served us our food and drinks with a smile .
# sentence: 267.0 out of 1880.0 in raw_data;
# the place 's decor and hidden bathrooms made for a good laugh .
# sentence: 268.0 out of 1880.0 in raw_data;
# the place 's decor and hidden bathrooms made for a good laugh .
# sentence: 269.0 out of 1880.0 in raw_data;
# i highly recommend visiting this restaurant and having dinner and drinks !
# sentence: 270.0 out of 1880.0 in raw_data;
# if you are the type of person who likes being scared and entertained , this is a great place to go and eat .
# sentence: 271.0 out of 1880.0 in raw_data;
# my husband and i thougt it would be great to go to the jekyll and hyde pub for our anniversary , and to our surprise it was fantastic .
# sentence: 272.0 out of 1880.0 in raw_data;
# the have over 100 different beers to offer thier guest so that made my husband very happy and the food was delicious , if i must recommend a dish it must be the pumkin tortelini .
# sentence: 273.0 out of 1880.0 in raw_data;
# the have over 100 different beers to offer thier guest so that made my husband very happy and the food was delicious , if i must recommend a dish it must be the pumkin tortelini .
# sentence: 274.0 out of 1880.0 in raw_data;
# the have over 100 different beers to offer thier guest so that made my husband very happy and the food was delicious , if i must recommend a dish it must be the pumkin tortelini .
# sentence: 275.0 out of 1880.0 in raw_data;
# please take my advice , go and try this place .
# sentence: 276.0 out of 1880.0 in raw_data;
# the bagel was huge .
# sentence: 277.0 out of 1880.0 in raw_data;
# the workers there also absolutely load the bagel with cream cheese ( gets a little messy ) .
# sentence: 278.0 out of 1880.0 in raw_data;
# this was my frist time at cafe st. bart 's and i must say how delicous the food and the service was .
# sentence: 279.0 out of 1880.0 in raw_data;
# this was my frist time at cafe st. bart 's and i must say how delicous the food and the service was .
# sentence: 280.0 out of 1880.0 in raw_data;
# i have to highly recommend the lobster roll - not to much mayo ; you can tell it was a fresh lobster .
# sentence: 281.0 out of 1880.0 in raw_data;
# i have to highly recommend the lobster roll - not to much mayo ; you can tell it was a fresh .
# sentence: 282.0 out of 1880.0 in raw_data;
# other guests enjoyed pizza , santa fe chopped salad and fish and chips .
# sentence: 283.0 out of 1880.0 in raw_data;
# other guests enjoyed pizza , santa fe chopped salad and fish and chips .
# sentence: 284.0 out of 1880.0 in raw_data;
# other guests enjoyed pizza , santa fe chopped salad and fish and chips .
# sentence: 285.0 out of 1880.0 in raw_data;
# i highly recommend cafe st. bart 's for their food , the ambience and wonderful service .
# sentence: 286.0 out of 1880.0 in raw_data;
# i highly recommend cafe st. bart 's for their food , the ambience and wonderful service .
# sentence: 287.0 out of 1880.0 in raw_data;
# i highly recommend cafe st. bart 's for their food , the ambience and wonderful service .
# sentence: 288.0 out of 1880.0 in raw_data;
# all the staff is absolutely professional ! !
# sentence: 289.0 out of 1880.0 in raw_data;
# this restaurant was way overhyped .
# sentence: 290.0 out of 1880.0 in raw_data;
# my chow fun and chow see was really bland and oily .
# sentence: 291.0 out of 1880.0 in raw_data;
# the scallion pancakes and fried dumplings were nothing out of the ordinary .
# sentence: 292.0 out of 1880.0 in raw_data;
# the scallion pancakes and fried dumplings were nothing out of the ordinary .
# sentence: 293.0 out of 1880.0 in raw_data;
# the service was the only thing good about this restaurant .
# sentence: 294.0 out of 1880.0 in raw_data;
# the service was the only thing good about this restaurant .
# sentence: 295.0 out of 1880.0 in raw_data;
# it 's boring on the inside , and our sushi was pretty below average ... the tuna was soggy and the other rolls had no flavor .
# sentence: 296.0 out of 1880.0 in raw_data;
# it 's boring on the inside , and our sushi was pretty below average ... the tuna was soggy and the other rolls had no flavor .
# sentence: 297.0 out of 1880.0 in raw_data;
# it 's boring on the inside , and our sushi was pretty below average ... the tuna was soggy and the other rolls had no flavor .
# sentence: 298.0 out of 1880.0 in raw_data;
# their pad penang is delicious and everything else is fantastic .
# sentence: 299.0 out of 1880.0 in raw_data;
# the price is reasonable although the service is poor .
# sentence: 300.0 out of 1880.0 in raw_data;
# fresh restaurant was amazing ... ... .. food was delicious and of course fresh .
# sentence: 301.0 out of 1880.0 in raw_data;
# fresh restaurant was amazing ... ... .. food was delicious and of course fresh .
# sentence: 302.0 out of 1880.0 in raw_data;
# hats off to the chef .
# sentence: 303.0 out of 1880.0 in raw_data;
# the salads are delicious , both refreshing and very spicy .
# sentence: 304.0 out of 1880.0 in raw_data;
# we had pam 's special fried fish and it was amazing .
# sentence: 305.0 out of 1880.0 in raw_data;
# great vibe , lots of people .
# sentence: 306.0 out of 1880.0 in raw_data;
# i did n't complain , i liked the atmosphere so much .
# sentence: 307.0 out of 1880.0 in raw_data;
# ambience is so cute and quaint , good for business although we were there on vacation .
# sentence: 308.0 out of 1880.0 in raw_data;
# salads were fantastic .
# sentence: 309.0 out of 1880.0 in raw_data;
# although we were looking for regular lettuce and some walnuts the salads we got were great .
# sentence: 310.0 out of 1880.0 in raw_data;
# ingredients are organic which is a real plus for me .
# sentence: 311.0 out of 1880.0 in raw_data;
# this is some really good , inexpensive sushi .
# sentence: 312.0 out of 1880.0 in raw_data;
# this is some really good , inexpensive sushi .
# sentence: 313.0 out of 1880.0 in raw_data;
# the spicy tuna roll is huge and probably the best that i 've had at this price range .
# sentence: 314.0 out of 1880.0 in raw_data;
# the spicy tuna roll is huge and probably the best that i 've had at this price range .
# sentence: 315.0 out of 1880.0 in raw_data;
# the spicy tuna roll is huge and probably the best that i 've had at this price range .
# sentence: 316.0 out of 1880.0 in raw_data;
# the yellowtail was particularly good as well .
# sentence: 317.0 out of 1880.0 in raw_data;
# i have reservations about the all you can eat deal , however -- the choices are fairly limited and you can probably order more food than you can eat for less than $ 18 by just going off the menu .
# sentence: 318.0 out of 1880.0 in raw_data;
# i have reservations about the all you can eat deal , however -- the choices are fairly limited and you can probably order more food than you can eat for less than $ 18 by just going off the menu .
# sentence: 319.0 out of 1880.0 in raw_data;
# in any event , this is a place i 'll be sure to stop by again when i 'm in this part of town .
# sentence: 320.0 out of 1880.0 in raw_data;
# big wong gets big ups for a fine establishment .
# sentence: 321.0 out of 1880.0 in raw_data;
# they have it all -- great price , food , and service .
# sentence: 322.0 out of 1880.0 in raw_data;
# they have it all -- great price , food , and service .
# sentence: 323.0 out of 1880.0 in raw_data;
# the atmosphere is noisy and the waiters are literally walking around doing things as fast as they can .
# sentence: 324.0 out of 1880.0 in raw_data;
# the atmosphere is noisy and the waiters are literally walking around doing things as fast as they can .
# sentence: 325.0 out of 1880.0 in raw_data;
# and it all comes at a very reasonable price ( congee , noodles , and rice dishes are no more than $ 3-6 each ) .
# sentence: 326.0 out of 1880.0 in raw_data;
# and it all comes at a very reasonable price ( congee , noodles , and rice dishes are no more than $ 3-6 each ) .
# sentence: 327.0 out of 1880.0 in raw_data;
# and it all comes at a very reasonable price ( congee , noodles , and rice dishes are no more than $ 3-6 each ) .
# sentence: 328.0 out of 1880.0 in raw_data;
# the takeout is great too since they give high quality tupperware as well .
# sentence: 329.0 out of 1880.0 in raw_data;
# this place is always very crowded and popular .
# sentence: 330.0 out of 1880.0 in raw_data;
# enjoyed a very nice caesar salad while my wife had arugula and goat cheese ... .both very tasty .
# sentence: 331.0 out of 1880.0 in raw_data;
# enjoyed a very nice caesar salad while my wife had arugula and goat cheese ... .both very tasty .
# sentence: 332.0 out of 1880.0 in raw_data;
# we both opted for a pasta dish and they were served timely and fresh .
# sentence: 333.0 out of 1880.0 in raw_data;
# we concluded with tiramisu chocolate cake , both were delicious .
# sentence: 334.0 out of 1880.0 in raw_data;
# we concluded with tiramisu chocolate cake , both were delicious .
# sentence: 335.0 out of 1880.0 in raw_data;
# i recently went to this restaurant with some co-workers for lunch and had an amazing time .
# sentence: 336.0 out of 1880.0 in raw_data;
# the staff was accomodating , the food was absolutely delicious and the place is lovely .
# sentence: 337.0 out of 1880.0 in raw_data;
# the staff was accomodating , the food was absolutely delicious and the place is lovely .
# sentence: 338.0 out of 1880.0 in raw_data;
# the staff was accomodating , the food was absolutely delicious and the place is lovely .
# sentence: 339.0 out of 1880.0 in raw_data;
# we even had a visit from the manager who wanted to make sure we were enjoying ourselves .
# sentence: 340.0 out of 1880.0 in raw_data;
# sometimes i get good food and ok service .
# sentence: 341.0 out of 1880.0 in raw_data;
# sometimes i get good food and ok service .
# sentence: 342.0 out of 1880.0 in raw_data;
# sometimes i get bad food and bad service , sometimes i get good good and bad service .
# sentence: 343.0 out of 1880.0 in raw_data;
# sometimes i get bad food and bad service , sometimes i get good good and bad .
# sentence: 344.0 out of 1880.0 in raw_data;
# sometimes i get bad food and bad service , sometimes i get good good and bad .
# sentence: 345.0 out of 1880.0 in raw_data;
# sometimes i get bad food and bad service , sometimes i get good and bad service .
# sentence: 346.0 out of 1880.0 in raw_data;
# the place is a bistro which means : simple dishes and wine served efficiently in a bustling atmosphere .
# sentence: 347.0 out of 1880.0 in raw_data;
# the place is a bistro which means : simple dishes and wine served efficiently in a bustling atmosphere .
# sentence: 348.0 out of 1880.0 in raw_data;
# the place is a bistro which means : simple dishes and wine served efficiently in a bustling atmosphere .
# sentence: 349.0 out of 1880.0 in raw_data;
# and where does patis go wrong ; no where .
# sentence: 350.0 out of 1880.0 in raw_data;
# and evaluated on those terms pastis is simply wonderful .
# sentence: 351.0 out of 1880.0 in raw_data;
# right off the l in brooklyn this is a nice cozy place with good pizza .
# sentence: 352.0 out of 1880.0 in raw_data;
# right off the l in brooklyn this is a nice cozy place with good pizza .
# sentence: 353.0 out of 1880.0 in raw_data;
# mine was a little burnt but still delicious with goat cheese and panchetta ( raddichio was kind of bitter though ) .
# sentence: 354.0 out of 1880.0 in raw_data;
# my friend got the mushroom pizza which tasted better .
# sentence: 355.0 out of 1880.0 in raw_data;
# the sangria was pretty tasty and good on a hot muggy day .
# sentence: 356.0 out of 1880.0 in raw_data;
# kind of a small place but i guess if they are not too busy might be able to fit a group or kids .
# sentence: 357.0 out of 1880.0 in raw_data;
# i started out with a bombay beer which was big enough for two .
# sentence: 358.0 out of 1880.0 in raw_data;
# service was slow , but the people were friendly .
# sentence: 359.0 out of 1880.0 in raw_data;
# service was slow , but the people were friendly .
# sentence: 360.0 out of 1880.0 in raw_data;
# it 's a nice place to relax and have conversation .
# sentence: 361.0 out of 1880.0 in raw_data;
# the food is authentic italian - delicious !
# sentence: 362.0 out of 1880.0 in raw_data;
# pizza is terrific , as is homemade pasta .
# sentence: 363.0 out of 1880.0 in raw_data;
# pizza is terrific , as is homemade pasta .
# sentence: 364.0 out of 1880.0 in raw_data;
# ambience is delightful , service impeccable .
# sentence: 365.0 out of 1880.0 in raw_data;
# ambience is delightful , service impeccable .
# sentence: 366.0 out of 1880.0 in raw_data;
# i 'm still mad that i had to pay for lousy food .
# sentence: 367.0 out of 1880.0 in raw_data;
# the hanger steak was like rubber and the tuna was flavorless not to mention it tasted like it had just been thawed .
# sentence: 368.0 out of 1880.0 in raw_data;
# the hanger steak was like rubber and the tuna was flavorless not to mention it tasted like it had just been thawed .
# sentence: 369.0 out of 1880.0 in raw_data;
# service was also horrible and the ambience is not that great .
# sentence: 370.0 out of 1880.0 in raw_data;
# service was also horrible and the ambience is not that great .
# sentence: 371.0 out of 1880.0 in raw_data;
# i go and eat out at many different restaurants and this is one place you have go and try .
# sentence: 372.0 out of 1880.0 in raw_data;
# this is my first time writing a review for a restaurant because the food and service was excellent .
# sentence: 373.0 out of 1880.0 in raw_data;
# this is my first time writing a review for a restaurant because the food and service was excellent .
# sentence: 374.0 out of 1880.0 in raw_data;
# the filet mignon dish was superb !
# sentence: 375.0 out of 1880.0 in raw_data;
# it 's a small cute restaurant .
# sentence: 376.0 out of 1880.0 in raw_data;
# i absolutely love this place ! ! !
# sentence: 377.0 out of 1880.0 in raw_data;
# i like the ambience , it 's very dark and original .
# sentence: 378.0 out of 1880.0 in raw_data;
# the sushi is amazing ! ! !
# sentence: 379.0 out of 1880.0 in raw_data;
# very affordable and excellent ambient !
# sentence: 380.0 out of 1880.0 in raw_data;
# we ordered some beef and noodle soup dishes from the thai section of the menu but nothing we got was thai .
# sentence: 381.0 out of 1880.0 in raw_data;
# we wo n't go to this place again for a good meal .
# sentence: 382.0 out of 1880.0 in raw_data;
# ...
# sentence: 1771.0 out of 1880.0 in raw_data;
# the place has a nice fit-out , some attractive furnishings and , from what i could tell , a reasonable wine list ( i was given the food menu when i asked for the carte des vins )
# sentence: 1772.0 out of 1880.0 in raw_data;
# the place has a nice fit-out , some attractive furnishings and , from what i could tell , a reasonable wine list ( i was given the food menu when i asked for the carte des vins )
# sentence: 1773.0 out of 1880.0 in raw_data;
# the place has a nice fit-out , some attractive furnishings and , from what i could tell , a reasonable wine list ( i was given the food menu when i asked for the carte des vins )
# sentence: 1774.0 out of 1880.0 in raw_data;
# how is this palce still open ?
# sentence: 1775.0 out of 1880.0 in raw_data;
# everything was going good until we got our meals .
# sentence: 1776.0 out of 1880.0 in raw_data;
# i took one look at the chicken and i was appalled .
# sentence: 1777.0 out of 1880.0 in raw_data;
# it was served with skin , over a bed of extremely undercooked spinach and mashed potatoes .
# sentence: 1778.0 out of 1880.0 in raw_data;
# i took one bite from the $ 24 salmon , and i have never , in the 17 years i have been going to restaurants tasted as fishy , as dry , and as bland as the one in flatbush farms .
# sentence: 1779.0 out of 1880.0 in raw_data;
# i took one bite from the $ 24 salmon , and i have never , in the 17 years i have been going to restaurants tasted as fishy , as dry , and as bland as the one in flatbush farms .
# sentence: 1780.0 out of 1880.0 in raw_data;
# at this point , the waitress comes over and asks us if everything was okay , i was literally so shocked that i was speechless and did n't say anything , and guess what , the walked away .
# sentence: 1781.0 out of 1880.0 in raw_data;
# so , i switch with my boyfriend again to see if maybe i could stomach the meat and spinach again , but the was so undercooked that i just could not bite through it .
# sentence: 1782.0 out of 1880.0 in raw_data;
# this is where it really really gets bad : the manager said , there is absolutely nothing we can do , it 's a matter of taste that she did n't like it , and i can not comp it .
# sentence: 1783.0 out of 1880.0 in raw_data;
# the manager came to the table and said we can do what we want , so we paid for what we did enjoy , the drinks and appetizers , and walked out .
# sentence: 1784.0 out of 1880.0 in raw_data;
# the manager came to the table and said we can do what we want , so we paid for what we did enjoy , the drinks and appetizers , and walked out .
# sentence: 1785.0 out of 1880.0 in raw_data;
# the manager came to the table and said we can do what we want , so we paid for what we did enjoy , the drinks and appetizers , and walked out .
# sentence: 1786.0 out of 1880.0 in raw_data;
# this staff should be fired .
# sentence: 1787.0 out of 1880.0 in raw_data;
# cirspy crust margherita pizza
# sentence: 1788.0 out of 1880.0 in raw_data;
# it was really good pizza .
# sentence: 1789.0 out of 1880.0 in raw_data;
# the crust was imazingly cooked well and pizza was fully loaded : ) : ) : )
# sentence: 1790.0 out of 1880.0 in raw_data;
# the crust was imazingly cooked well and pizza was fully loaded : ) : ) : )
# sentence: 1791.0 out of 1880.0 in raw_data;
# single worst restaurant in manhattan
# sentence: 1792.0 out of 1880.0 in raw_data;
# i 'll being with a couple of positives : cool decor , good pita and hummus , and grilled octopus that was actually pretty tasty .
# sentence: 1793.0 out of 1880.0 in raw_data;
# i 'll being with a couple of positives : cool decor , good pita and hummus , and grilled octopus that was actually pretty tasty .
# sentence: 1794.0 out of 1880.0 in raw_data;
# i 'll being with a couple of positives : cool decor , good pita and hummus , and grilled octopus that was actually pretty tasty .
# sentence: 1795.0 out of 1880.0 in raw_data;
# i 'll being with a couple of positives : cool decor , good pita and hummus , and grilled octopus that was actually pretty tasty .
# sentence: 1796.0 out of 1880.0 in raw_data;
# if i could give 0 stars i would do so for this place .
# sentence: 1797.0 out of 1880.0 in raw_data;
# this place ... god where do i begin .
# sentence: 1798.0 out of 1880.0 in raw_data;
# it is quite a spectacular scene i 'll give them that .
# sentence: 1799.0 out of 1880.0 in raw_data;
# the decor however seems to be the distraction so you wo n't notice that you just payed 300 bucks for some cold eggplant that took 2 frickin hours to come ! ! ! !
# sentence: 1800.0 out of 1880.0 in raw_data;
# the decor however seems to be the distraction so you wo n't notice that you just payed 300 bucks for some cold eggplant that took 2 frickin hours to come ! ! ! !
# sentence: 1801.0 out of 1880.0 in raw_data;
# the decor however seems to be the distraction so you wo n't notice that you just payed 300 bucks for some cold eggplant that took 2 frickin hours to come ! ! ! !
# sentence: 1802.0 out of 1880.0 in raw_data;
# how this place survives the competitive west village market in this economy , or any other for that matter , is beyond me .
# sentence: 1803.0 out of 1880.0 in raw_data;
# great hot dogs !
# sentence: 1804.0 out of 1880.0 in raw_data;
# though it 's been crowded most times i 've gone here , bark always delivers on their food .
# sentence: 1805.0 out of 1880.0 in raw_data;
# though it 's been crowded most times i 've gone here , bark always delivers on their food .
# sentence: 1806.0 out of 1880.0 in raw_data;
# the hot dogs are top notch , and they 're slamwich is amazing !
# sentence: 1807.0 out of 1880.0 in raw_data;
# the hot dogs are top notch , and they 're slamwich is amazing !
# sentence: 1808.0 out of 1880.0 in raw_data;
# going to bark is always worth the train ride , and will make your tongue and belly very happy !
# sentence: 1809.0 out of 1880.0 in raw_data;
# only complaint is the pricing -- i believe it would be more reasonable to pay a dollar less on each item listed on the menu .
# sentence: 1810.0 out of 1880.0 in raw_data;
# but nonetheless -- great spot , great food .
# sentence: 1811.0 out of 1880.0 in raw_data;
# but nonetheless -- great spot , great food .
# sentence: 1812.0 out of 1880.0 in raw_data;
# fabulous food - if the front of house staff do n't put you off –
# sentence: 1813.0 out of 1880.0 in raw_data;
# fabulous food - if the front of house staff do n't put you off –
# sentence: 1814.0 out of 1880.0 in raw_data;
# each time we 've been , the front of house staff ( not the waiters - they 're fantastic - but the people who greet and seat you ) has been so hideous to us that were it not for the exceptional fish dishes i would never return .
# sentence: 1815.0 out of 1880.0 in raw_data;
# each time we 've been , the front of house staff ( not the waiters - they 're fantastic - but the people who greet and seat you ) has been so hideous to us that were it not for the exceptional fish dishes i would never return .
# sentence: 1816.0 out of 1880.0 in raw_data;
# each time we 've been , the front of house staff ( not the waiters - they 're fantastic - but the people who greet and seat you ) has been so hideous to us that were it not for the exceptional fish dishes i would never return .
# sentence: 1817.0 out of 1880.0 in raw_data;
# as bfc does n't take reservations you almost always have to wait by the bar - and be abused by the front of house staff until you are seated , which can be over an hour later !
# sentence: 1818.0 out of 1880.0 in raw_data;
# as bfc does n't take reservations you almost always have to wait by the bar - and be abused by the front of house staff until you are seated , which can be over an hour later !
# sentence: 1819.0 out of 1880.0 in raw_data;
# the frizzy retro girl ( with winged/ dame edna glasses ) will yell at you if you try to order a drink .
# sentence: 1820.0 out of 1880.0 in raw_data;
# i 'd be horrified if my staff were turning away customers so early and so rudely !
# sentence: 1821.0 out of 1880.0 in raw_data;
# there 's another girl who i ca n't describe , she is about 5'6 '' with brown hair , who eavesdrops on your conversation and chimes in - except she only hears the last part of what you said , so her uninvited opinions are often out of context and nothing to do with what you 're *really* talking about .
# sentence: 1822.0 out of 1880.0 in raw_data;
# considering you will spend at least $ 60 a head , i expect better service .
# sentence: 1823.0 out of 1880.0 in raw_data;
# $t$- '' eat and get out '' maitre-d
# sentence: 1824.0 out of 1880.0 in raw_data;
# the food and service were fine , however the maitre-d was incredibly unwelcoming and arrogant .
# sentence: 1825.0 out of 1880.0 in raw_data;
# the food and service were fine , however the maitre-d was incredibly unwelcoming and arrogant .
# sentence: 1826.0 out of 1880.0 in raw_data;
# the food and service were fine , however the maitre-d was incredibly unwelcoming and arrogant .
# sentence: 1827.0 out of 1880.0 in raw_data;
# while finishing our meals which included a high-end bottle of wine , our son 's fiance joined us for a glass of wine and dessert .
# sentence: 1828.0 out of 1880.0 in raw_data;
# this guy refused to seat her and she left , followed shortly by the four of us , but not before i told him that in my 40 years of world travel , including paris , that i had never seen such a display of bad behavior by a frontman in a restaurant .
# sentence: 1829.0 out of 1880.0 in raw_data;
# a word to the wise : you ca n't dine here and disturb the maitre-d 's sense of `` table turnover '' , as whacked as it is , or else .
# sentence: 1830.0 out of 1880.0 in raw_data;
# best meal in a long time !
# sentence: 1831.0 out of 1880.0 in raw_data;
# mussles and calamari were superb saturday evening .
# sentence: 1832.0 out of 1880.0 in raw_data;
# mussles and calamari were superb saturday evening .
# sentence: 1833.0 out of 1880.0 in raw_data;
# i had the lamb special which was perfect .
# sentence: 1834.0 out of 1880.0 in raw_data;
# my father had the flank steak which was very good , and my mother had the swordfish .
# sentence: 1835.0 out of 1880.0 in raw_data;
# the four seasons restaurant is a great experience .
# sentence: 1836.0 out of 1880.0 in raw_data;
# the food is great and the environment is even better .
# sentence: 1837.0 out of 1880.0 in raw_data;
# the food is great and the environment is even better .
# sentence: 1838.0 out of 1880.0 in raw_data;
# taking hot dogs to the next level
# sentence: 1839.0 out of 1880.0 in raw_data;
# at first glance this place seems a bit pricey for a hot dog joint , but at bark you do n't just get your average hot dog .
# sentence: 1840.0 out of 1880.0 in raw_data;
# at first glance this place seems a bit pricey for a hot dog joint , but at bark you do n't just get your average .
# sentence: 1841.0 out of 1880.0 in raw_data;
# here the hot dog is elevated to the level of a real entree with numerous variations available .
# sentence: 1842.0 out of 1880.0 in raw_data;
# here the hot dog is elevated to the level of a real entree with numerous variations available .
# sentence: 1843.0 out of 1880.0 in raw_data;
# great atmosphere
# sentence: 1844.0 out of 1880.0 in raw_data;
# i highly recommend the fish tacos , everything else was ok .
# sentence: 1845.0 out of 1880.0 in raw_data;
# cool atmosphere , the fire place in the back really ads to it but needs a bit more heat throughout on a cold night .
# sentence: 1846.0 out of 1880.0 in raw_data;
# cool atmosphere , the fire place in the back really ads to it but needs a bit more heat throughout on a cold night .
# sentence: 1847.0 out of 1880.0 in raw_data;
# poor service and management
# sentence: 1848.0 out of 1880.0 in raw_data;
# poor service and management
# sentence: 1849.0 out of 1880.0 in raw_data;
# don ’ t go to this place !
# sentence: 1850.0 out of 1880.0 in raw_data;
# had an awful experience at casa la femme on a saturday dinner .
# sentence: 1851.0 out of 1880.0 in raw_data;
# the manager was rude and handled the situation extremely poorly .
# sentence: 1852.0 out of 1880.0 in raw_data;
# can ’ t believe how an expensive nyc restaurant can be so disrespectful to its clients .
# sentence: 1853.0 out of 1880.0 in raw_data;
# the food is very good , but not outstanding .
# sentence: 1854.0 out of 1880.0 in raw_data;
# there is no way it justifies the accolades it receives , the attitude of the staff or the wait for a table .
# sentence: 1855.0 out of 1880.0 in raw_data;
# there is no way it justifies the accolades it receives , the attitude of the staff or the wait for a table .
# sentence: 1856.0 out of 1880.0 in raw_data;
# mistakes happen , but they are usually accompanied by an apology , perhaps even a glass of wine ... but not the grunt that we received from the al di la staff .
# sentence: 1857.0 out of 1880.0 in raw_data;
# the bread was stale , the salad was overpriced and empty .
# sentence: 1858.0 out of 1880.0 in raw_data;
# the bread was stale , the salad was overpriced and empty .
# sentence: 1859.0 out of 1880.0 in raw_data;
# the bread was stale , the salad was overpriced and empty .
# sentence: 1860.0 out of 1880.0 in raw_data;
# the pasta was well cooked , did n't have enough sauce though or flavor .
# sentence: 1861.0 out of 1880.0 in raw_data;
# the pasta was well cooked , did n't have enough sauce though or flavor .
# sentence: 1862.0 out of 1880.0 in raw_data;
# the pasta was well cooked , did n't have enough sauce though or flavor .
# sentence: 1863.0 out of 1880.0 in raw_data;
# the hostess was rude and i got a distinct feeling that they did not want to serve us .
# sentence: 1864.0 out of 1880.0 in raw_data;
# the only thing that my friend left out is that when we sat down at the bar the bartender disappeared .
# sentence: 1865.0 out of 1880.0 in raw_data;
# i asked for a menu and the same waitress looked at my like i was insane .
# sentence: 1866.0 out of 1880.0 in raw_data;
# i was shocked that my friends wanted to stay after the waitress said , `` can i help you '' and `` how many are in your party . ''
# sentence: 1867.0 out of 1880.0 in raw_data;
# shame on this place for the horrible rude staff and non-existent customer service .
# sentence: 1868.0 out of 1880.0 in raw_data;
# shame on this place for the horrible rude staff and non-existent customer service .
# sentence: 1869.0 out of 1880.0 in raw_data;
# bad staff
# sentence: 1870.0 out of 1880.0 in raw_data;
# i generally like this place .
# sentence: 1871.0 out of 1880.0 in raw_data;
# the food is good .
# sentence: 1872.0 out of 1880.0 in raw_data;
# the design of the space is good .
# sentence: 1873.0 out of 1880.0 in raw_data;
# but the service is horrid !
# sentence: 1874.0 out of 1880.0 in raw_data;
# i was there for brunch recently , and we were tag teamed by a waitress and a waiter .
# sentence: 1875.0 out of 1880.0 in raw_data;
# i was there for brunch recently , and we were tag teamed by a waitress and a waiter .
# sentence: 1876.0 out of 1880.0 in raw_data;
# the waiter delivered our food while holding what appeared to be a plastic bag of garbage in one hand .
# sentence: 1877.0 out of 1880.0 in raw_data;
# the waitress came to check in on us every few minutes , and began to clear the plates while half of us were still eating ( a big pet peeve of mine that happens almost everywhere , so i try to ignore it ) .
# sentence: 1878.0 out of 1880.0 in raw_data;
# i wish i could like this place more , and i wish someone would retrain the staff .
# sentence: 1879.0 out of 1880.0 in raw_data;
# i wish i could like this place more , and i wish someone would retrain the staff .
# sentence: 1880.0 out of 1880.0 in raw_data;
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-f65982f9e05e> in <module>
#       8       for i in range(j, j + 150, 3):  # Was 0*3, 2530*3, 3
#       9           print("sentence: " + str(i / 3) + " out of " + str(len(lines) / 3) + " in " + "raw_data;")
# ---> 10           target = lines[i + 1].lower().split()
#      11           words = lines[i].lower().split()
#      12           words_l, words_r = [], []
#
# IndexError: list index out of range
